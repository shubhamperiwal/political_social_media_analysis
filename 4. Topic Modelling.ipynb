# %% [markdown]
# # Topic Modelling

# %% [markdown]
# In this project, I will try to compare the tweets of Donald Trump, Barrack Obama, and Hillary Clinton to come up with meaningful insights

# %% [markdown]
# In this notebook, I will try to classify their tweets under different topics to judge who talks about what

# %% [markdown]
# There are 3 CSV files which will be used:
# 1. DonaldTrumpClean
# 2. BarackObamaClean
# 3. HillaryClintonClean
#
# All 3 have the same structure
# date,retweet,text,author

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string

import gensim
from gensim import corpora

# %% [markdown]
# Read the clean data

# %%
trump = pd.read_csv("data/DonaldTrumpClean.csv")
obama = pd.read_csv("data/BarackObamaClean.csv")
clinton = pd.read_csv("data/HillaryClintonClean.csv")

# %%
print(len(trump), len(obama), len(clinton))
# Out:
# 8439 2125 3256

# %% [markdown]
# ## Topic Modelling

# %%
trumpTweetList = list(trump.text)

# %% [markdown]
# ### Cleaning and Preprocessing

# %% [markdown]
# Cleaning is an important step before any text mining task, in this step, we will remove the punctuations, stopwords and normalize the corpus.

# %%
stop_words = set(stopwords.words('english'))
stop_words.update(['@realdonaldtrump', '@realdonaldtrump.', '.@realdonaldtrump', 'trump', 'donald', 'Donald trump'])
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()

def clean(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop_words])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)    
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return stop_free

doc_clean = [clean(doc).split() for doc in trumpTweetList]

# %%
doc_clean
# Out:
# [['statement.'],
#  ['really', 'america?', 'terrible!'],
#  ['media',
#   'establishment',
#   'want',
#   'race',
#   'badly',
#   'never',
#   'drop',
#   'race,',
#   'never',
#   'let',
#   'supporters',
#   'down!',
#   '#maga'],
#  ['wow,',
#   '@cnn',
#   'town',
#   'hall',
#   'questions',
#   'given',
#   'crooked',
#   'hillary',
#   'clinton',
#   'advance',
#   'big',
#   'debates',
#   'bernie',
#   'sanders.',
#   'hillary',
#   'cnn',
#   'fraud!'],
#  ['debate', 'polls', 'look', 'great', 'thank', 'you!#maga', '#americafirst'],
#  ['saying',
#   'clinton',
#   'campaigns',
#   'anticatholic',
#   'bigotry',
#   'http//bit.ly/2dcbtvkcrooked'],
#  ['thank',
#   'u.s.',
#   'navy',
#   'protecting',
#   'country,',
#   'times',
#   'peace',
#   'war.',
#   'together,',
#   'make',
#   'america',
#   'safe',
#   'great',
#   'again!'],
#  ['little',
#   'pickup',
#   'dishonest',
#   'media',
#   'incredible',
#   'information',
#   'provided',
#   'wikileaks.',
#   'dishonest!',
#   'rigged',
#   'system!'],
#  ['thank',
#   'florida',
#   'movement',
#   'never',
#   'seen',
#   'never',
#   'seen',
#   'again.',
#   'lets',
#   'get',
#   '#votetrumppence16',
#   '11/8!',
#   '#maga'],
#  ['foul',
#   'mouthed',
#   'sen.',
#   'john',
#   'mccain',
#   'begged',
#   'support',
#   'primary',
#   'gave,',
#   'won,',
#   'dropped',
#   'locker',
#   'room',
#   'remarks!'],
#  ['disloyal',
#   'rs',
#   'far',
#   'difficult',
#   'crooked',
#   'hillary.',
#   'come',
#   'sides.',
#   'dont',
#   'know',
#   'win',
#   'teach',
#   'them!'],
#  ['exception',
#   'cheating',
#   'bernie',
#   'nom',
#   'dems',
#   'always',
#   'proven',
#   'far',
#   'loyal',
#   'republicans!'],
#  ['nice', 'shackles', 'taken', 'fight', 'america', 'way', 'want', 'to.'],
#  ['weak',
#   'ineffective',
#   'leader,',
#   'paul',
#   'ryan,',
#   'bad',
#   'conference',
#   'call',
#   'members',
#   'went',
#   'wild',
#   'disloyalty.'],
#  ['despite',
#   'winning',
#   'second',
#   'debate',
#   'landslide',
#   'every',
#   'poll,',
#   'hard',
#   'well',
#   'paul',
#   'ryan',
#   'others',
#   'give',
#   'zero',
#   'support!'],
#  ['wow,',
#   '@cnn',
#   'got',
#   'caught',
#   'fixing',
#   'focus',
#   'group',
#   'order',
#   'make',
#   'crooked',
#   'hillary',
#   'look',
#   'better.',
#   'really',
#   'pathetic',
#   'totally',
#   'dishonest!'],
#  ['.@hillaryclinton', 'law!#debates2016'],
#  ['team',
#   'deplorables',
#   'taking',
#   'twitter',
#   'account',
#   'tonights',
#   '#debate#makeamericagreatagain'],
#  ['many',
#   'selfrighteous',
#   'hypocrites.',
#   'watch',
#   'poll',
#   'numbers',
#   'elections',
#   'go',
#   'down!'],
#  ['@maidaa17',
#   'gop',
#   'traitors!',
#   'supporting',
#   'u',
#   'voting',
#   'her,',
#   'destroying',
#   'america.'],
#  ['wow,',
#   'hear',
#   'bill',
#   'clintons',
#   'statement',
#   'bad',
#   'obamacare',
#   'is.',
#   'hillary',
#   'happy.',
#   'saying,',
#   'repeal',
#   'replace!'],
#  ['watching',
#   'great',
#   'governor',
#   '@mikepence',
#   'live',
#   'tweeting',
#   'vp',
#   'debate',
#   'tonight',
#   'starting',
#   '830pm',
#   'est!',
#   'enjoy!'],
#  ['announced',
#   'iraq',
#   'u.s.',
#   'preparing',
#   'battle',
#   'reclaim',
#   'mosul.',
#   'announce',
#   'this?',
#   'makes',
#   'mission',
#   'much',
#   'harder!'],
#  ['melania',
#   'extend',
#   'warmest',
#   'greetings',
#   'observing',
#   'rosh',
#   'hashanah',
#   'united',
#   'states,',
#   'israel,',
#   'around',
#   'world.'],
#  ['bernie',
#   'pull',
#   'endorsement',
#   'crooked',
#   'hillary',
#   'decieved',
#   'attacked',
#   'supporters.'],
#  ['@trumplican2016',
#   'massive',
#   'turnout',
#   'you,',
#   'mr.',
#   'polls',
#   'dont',
#   'register',
#   'pulse',
#   'people!'],
#  ['created',
#   'tens',
#   'thousands',
#   'jobs',
#   'bring',
#   'back',
#   'great',
#   'american',
#   'prosperity.',
#   'hillary',
#   'created',
#   'jobs',
#   'fbi',
#   'doj!'],
#  ['know',
#   'complex',
#   'tax',
#   'laws',
#   'better',
#   'anyone',
#   'ever',
#   'run',
#   'president',
#   'one',
#   'fix',
#   'them.',
#   '#failing@nytimes'],
#  ['wow,',
#   'saw',
#   'really',
#   'bad',
#   '@cnn',
#   'ratings.',
#   'people',
#   'dont',
#   'want',
#   'watch',
#   'bad',
#   'product',
#   'builds',
#   'crooked',
#   'hillary.'],
#  ['socalled',
#   'commission',
#   'presidential',
#   'debates',
#   'admitted',
#   'us',
#   'djt',
#   'audio',
#   'sound',
#   'level',
#   'bad.',
#   'didnt',
#   'fix',
#   'it?'],
#  ['crooked',
#   'h',
#   'nasty',
#   'sanders',
#   'supporters',
#   'behind',
#   'closed',
#   'doors.',
#   'owned',
#   'wall',
#   'st',
#   'politicians,',
#   'hrc',
#   'you.http//www.politico.com/story/2016/09/hillaryclintonberniesanderssupportersaudioleak228997'],
#  ['believe',
#   '#americafirst',
#   'means',
#   'family',
#   'first!',
#   'childcare',
#   'plan',
#   'reflects',
#   'needs',
#   'modern',
#   'workingclass',
#   'families.',
#   '#imwithyou'],
#  ['people',
#   'knocking',
#   'tweeting',
#   'three',
#   'oclock',
#   'morning,',
#   'least',
#   'know',
#   'there,',
#   'awake,',
#   'answer',
#   'call!'],
#  ['isnt',
#   'hillary',
#   '50',
#   'points',
#   'ahead?',
#   'maybe',
#   'email',
#   'scandal,',
#   'policies',
#   'spread',
#   'isis,',
#   'calling',
#   'millions',
#   'americans',
#   'deplorables!'],
#  ['people',
#   'really',
#   'smart',
#   'cancelling',
#   'subscriptions',
#   'dallas',
#   'arizona',
#   'papers',
#   'usa',
#   'today',
#   'lose',
#   'readers!',
#   'people',
#   'get',
#   'it!'],
#  ['remember,',
#   'dont',
#   'believe',
#   'sources',
#   'said',
#   'dishonest',
#   'media.',
#   'dont',
#   'name',
#   'sources,',
#   'sources',
#   'dont',
#   'exist.'],
#  ['wow,',
#   'crooked',
#   'hillary',
#   'duped',
#   'used',
#   'worst',
#   'miss',
#   'u.',
#   'hillary',
#   'floated',
#   'angel',
#   'without',
#   'checking',
#   'past,',
#   'terrible!'],
#  ['anytime',
#   'see',
#   'story',
#   'campaign',
#   'saying',
#   'sources',
#   'said,',
#   'believe',
#   'it.',
#   'sources,',
#   'made',
#   'lies!'],
#  ['wow,',
#   'see',
#   'badly',
#   '@cnn',
#   'clinton',
#   'news',
#   'network',
#   'ratings.',
#   'people',
#   'like',
#   '@donlemon,',
#   'could',
#   'expect',
#   'more?'],
#  ['hillary',
#   'profits',
#   'rigged',
#   'system,',
#   'fighting',
#   'you!',
#   'remember',
#   'simple',
#   'phrase',
#   '#followthemoney',
#   'https//www.facebook.com/donaldtrump/videos/10157784190830725/'],
#  ['condolences',
#   'involved',
#   'todays',
#   'horrible',
#   'accident',
#   'nj',
#   'deepest',
#   'gratitude',
#   'amazing',
#   'first',
#   'responders.'],
#  ['every',
#   'online',
#   'poll,',
#   'time',
#   'magazine,',
#   'drudge',
#   'etc.,',
#   'winning',
#   'debate.',
#   'thank',
#   'fox',
#   'friends',
#   'reporting!'],
#  ['supporters',
#   'best!',
#   '18',
#   'million',
#   'hardworking',
#   'people',
#   'know',
#   'again!',
#   'shatter',
#   'recordhttp//bit.ly/shatterrecords'],
#  ['unbelievable',
#   'evening',
#   'melbourne,',
#   'florida',
#   'w/',
#   '15,000',
#   'supporters',
#   'additional',
#   '12,000',
#   'could',
#   'get',
#   'in.',
#   'thank',
#   'you!',
#   '#trumptrain',
#   '#maga'],
#  ['great',
#   'afternoon',
#   'little',
#   'havana',
#   'hispanic',
#   'community',
#   'leaders.',
#   'thank',
#   'support!',
#   '#imwithyou'],
#  ['last',
#   '24',
#   'hrs.',
#   'raised',
#   '13m',
#   'online',
#   'donations',
#   'national',
#   'call',
#   'day,',
#   'still',
#   'going!',
#   'thank',
#   'america!',
#   '#maga'],
#  ['well,',
#   'theyre',
#   'saying',
#   'nbc',
#   'presidential',
#   'forum,',
#   'last',
#   'night',
#   'big',
#   'debate.',
#   'nice!'],
#  ['thank',
#   'you!',
#   '#trumpwon',
#   '#magahttp//www.dailymail.co.uk/news/article3809204/mostsnappollstrumpwinningdebatelandslide.html'],
#  ['hillarys',
#   'failing',
#   '30',
#   'years',
#   'getting',
#   'job',
#   'done',
#   'never',
#   'change.'],
#  ['#1', 'trend', 'twitter', 'right', '#trumpwon', 'thank', 'you!'],
#  ['every',
#   'poll',
#   'last',
#   'nights',
#   'presidential',
#   'debate',
#   'except',
#   'little',
#   'watched',
#   '@cnn',
#   'poll.'],
#  ['bar',
#   'full',
#   'undecideds',
#   'democratshttp//nypost.com/2016/09/26/thebestdebatetakescomefrominsidethebar/'],
#  ['really',
#   'enjoyed',
#   'debate',
#   'last',
#   'night.crooked',
#   'hillary',
#   'says',
#   'going',
#   'many',
#   'things.why',
#   'hasnt',
#   'done',
#   'last',
#   '30',
#   'years?'],
#  ['thank',
#   'you!',
#   'four',
#   'new',
#   '#debatenight',
#   'polls',
#   'movement',
#   'winning.',
#   'together,',
#   'make',
#   'america',
#   'safe',
#   'great',
#   'again!http//www.donaldjtrump.com'],
#  ['.@drudgereports',
#   'first',
#   'presidential',
#   'debate',
#   'polltrump',
#   '80clinton',
#   '20join',
#   'movement',
#   'today',
#   'lets',
#   '#maga!',
#   'http//www.donaldjtrump.com'],
#  ['.@newtgingrich', 'said', 'historic', 'victory', 'trump.', 'nice!'],
#  ['wow,',
#   'great',
#   'debate',
#   'polls',
#   'except',
#   '@cnn',
#   'dont',
#   'watch.',
#   'thank',
#   'you!'],
#  ['thank',
#   'governor',
#   '@mikepence!lets',
#   'make',
#   'america',
#   'safe',
#   'great',
#   'american',
#   'people.',
#   '#americafirst',
#   '#debates2016https//twitter.com/mikepence/status/780615043809435649'],
#  ['thank', 'senator', '@tedcruz!#debates2016', '#maga'],
#  ['russia',
#   'warheads',
#   'ever,',
#   'n',
#   'korea',
#   'testing',
#   'nukes,',
#   'iran',
#   'got',
#   'sweetheart',
#   'deal',
#   'keep',
#   'theirs.',
#   'thanks,',
#   '@hillaryclinton.'],
#  ['hillary',
#   'clinton',
#   'failed',
#   'world.',
#   'libyasyriairaniraqasia',
#   'pivotrussian',
#   'resetbenghazi#debatenight'],
#  ['stand', 'police', 'protect', 'americans!', '#debates2016', '#maga'],
#  ['simple',
#   'fact',
#   '@hillaryclinton',
#   'typical',
#   'politician',
#   'talk,',
#   'action.',
#   '#debates2016'],
#  ['hillarys', 'bad', 'tax', 'habit!'],
#  ['.@hillaryclinton',
#   'part',
#   'rigged',
#   'dc',
#   'system',
#   '30',
#   'years?',
#   'would',
#   'take',
#   'policy',
#   'advice',
#   'her?',
#   '#debates2016'],
#  ['isnt', 'hillary', 'clinton', '50', 'points', 'ahead?#debatenight'],
#  ['team',
#   'deplorables',
#   'managing',
#   'twitter',
#   'account',
#   'evenings',
#   'debate.',
#   'tune',
#   'in!#debatenight',
#   '#trumppence16'],
#  ['new',
#   'national',
#   'bloomberg',
#   'poll',
#   'released',
#   'thank',
#   'you!',
#   'join',
#   'movement',
#   'http//www.donaldjtrump.com.',
#   '#trumptrain',
#   '#maga'],
#  ['really',
#   'sad',
#   'news',
#   'great',
#   'arnold',
#   'palmer,',
#   'king,',
#   'died.',
#   'noone',
#   'like',
#   'true',
#   'champion!',
#   'truly',
#   'missed.'],
#  ['five',
#   'people',
#   'killed',
#   'washington',
#   'state',
#   'middle',
#   'eastern',
#   'immigrant.',
#   'many',
#   'people',
#   'died',
#   'weekend',
#   'ohio',
#   'drug',
#   'overdoses.',
#   'n.c.',
#   'riots!'],
#  ['readout',
#   'meeting',
#   'israeli',
#   'prime',
#   'minister',
#   'benjamin',
#   'netanyahuhttps//www.facebook.com/donaldtrump/posts/101577591495907250'],
#  ['looking',
#   'forward',
#   'meeting',
#   'benjamin',
#   'netanyahu',
#   'tower',
#   '1000',
#   'a.m.'],
#  ['bernie',
#   'sanders',
#   'gave',
#   'hillary',
#   'dem',
#   'nomination',
#   'gave',
#   'emails.',
#   'issue',
#   'gotten',
#   'bigger!'],
#  ['many',
#   'team',
#   'staff',
#   'bernie',
#   'sanders',
#   'treated',
#   'badly',
#   'hillary',
#   'clinton',
#   'campaign',
#   'like',
#   'trade,',
#   'lot!'],
#  ['dopey',
#   'mark',
#   'cuban',
#   'failed',
#   'benefactor',
#   'fame',
#   'wants',
#   'sit',
#   'front',
#   'row,',
#   'perhaps',
#   'put',
#   'gennifer',
#   'flowers',
#   'right',
#   'alongside',
#   'him!'],
#  ['@kellyannepolls',
#   'headed',
#   'win,',
#   'says',
#   'professor',
#   'predicted',
#   '30',
#   'years',
#   'presidential',
#   'outcomes',
#   'http//wpo.st/hqg2'],
#  ['@sentedcruz',
#   'endorsement',
#   'wonderful',
#   'surprise.',
#   'greatly',
#   'appreciate',
#   'support!',
#   'tremendous',
#   'victory',
#   'november',
#   '8th.'],
#  ['crooked',
#   'hillarys',
#   'bad',
#   'judgement',
#   'forced',
#   'announce',
#   'would',
#   'go',
#   'charlotte',
#   'saturday',
#   'grandstand.',
#   'dem',
#   'pols',
#   'said',
#   'way,',
#   'dumb!'],
#  ['spoke',
#   'governor',
#   '@patmccrorync',
#   'north',
#   'carolina',
#   'today.',
#   'tremendous',
#   'job',
#   'tough',
#   'circumstances.'],
#  ['great',
#   'new',
#   'polls!',
#   'thank',
#   'nevada,',
#   'north',
#   'carolina',
#   'ohio.',
#   'join',
#   'movement',
#   'today',
#   'lets',
#   '#maga!http//www.donaldjtrump.com'],
#  ['hopefully',
#   'violence',
#   'unrest',
#   'charlotte',
#   'come',
#   'immediate',
#   'end.',
#   'injured,',
#   'get',
#   'well',
#   'soon.',
#   'need',
#   'unity',
#   'leadership.'],
#  ['situations',
#   'tulsa',
#   'charlotte',
#   'tragic.',
#   'must',
#   'come',
#   'together',
#   'make',
#   'america',
#   'safe',
#   'again.'],
#  ['movement',
#   'campaign.',
#   'leaving',
#   'past',
#   'behind,',
#   'changing',
#   'future.',
#   'together,',
#   'make',
#   'america',
#   'safe',
#   'great',
#   'again!'],
#  ['thank',
#   'kenansville,',
#   'north',
#   'carolina!',
#   'remember',
#   'november',
#   '8th,',
#   'special',
#   'interest',
#   'gravy',
#   'train',
#   'coming',
#   'abrupt',
#   'end!',
#   '#maga'],
#  ['thank',
#   'high',
#   'point,',
#   'nc!',
#   'fight',
#   'every',
#   'neglected',
#   'part',
#   'nation',
#   'fight',
#   'bring',
#   'us',
#   'together',
#   'one',
#   'american',
#   'people!'],
#  ['hillary',
#   'clinton',
#   'taking',
#   'day',
#   'again,',
#   'needs',
#   'rest.',
#   'sleep',
#   'well',
#   'hillary',
#   'see',
#   'debate!'],
#  ['people',
#   'notice',
#   'hillary',
#   'copying',
#   'airplane',
#   'rallies',
#   'puts',
#   'plane',
#   'behind',
#   'like',
#   'beginning.'],
#  ['crooked',
#   'hillary',
#   'fighting',
#   'isis,',
#   'whatever',
#   'doing,',
#   'years.',
#   'new',
#   'ideas.',
#   'time',
#   'change.'],
#  ['together,',
#   'make',
#   'america',
#   'safe',
#   'great',
#   'again!',
#   '#imwithyou',
#   '#americafirst'],
#  ['hillary',
#   'clintons',
#   'weakness',
#   'secretary',
#   'state,',
#   'emboldened',
#   'terrorists',
#   'world..cont',
#   'http//bit.ly/2cnwnwe'],
#  ['someone',
#   'told',
#   'ok',
#   'turns',
#   'terrorist',
#   'wants',
#   'destroy',
#   'country',
#   'people',
#   'get',
#   'thru',
#   'system?'],
#  ['great',
#   'job',
#   'law',
#   'enforcement!',
#   'proud',
#   'embrace',
#   'without',
#   'them,',
#   'dont',
#   'country!'],
#  ['terrible',
#   'attacks',
#   'ny,',
#   'nj',
#   'mn',
#   'weekend.',
#   'thinking',
#   'victims,',
#   'families',
#   'americans!',
#   'need',
#   'strong!'],
#  ['leadership',
#   'obama',
#   'clinton,',
#   'americans',
#   'experienced',
#   'attacks',
#   'home',
#   'victories',
#   'abroad.',
#   'time',
#   'change',
#   'playbook!'],
#  ['happy', 'birthday', 'united', 'states', 'air', 'force!!'],
#  ['would',
#   'like',
#   'express',
#   'warmest',
#   'regards,',
#   'best',
#   'wishes',
#   'condolences',
#   'families',
#   'victims',
#   'horrible',
#   'bombing',
#   'nyc.'],
#  ['lawyers',
#   'want',
#   'sue',
#   'failing',
#   '@nytimes',
#   'badly',
#   'irresponsible',
#   'intent.',
#   'said',
#   'now,',
#   'watching.',
#   'really',
#   'disgusting'],
#  ['failing',
#   '@nytimes',
#   'gone',
#   'nuts',
#   'crooked',
#   'hillary',
#   'badly.',
#   'willing',
#   'say',
#   'anything,',
#   'become',
#   'laughingstock',
#   'rag!'],
#  ['wacky',
#   '@nytimesdowd,',
#   'hardly',
#   'knows',
#   'me,',
#   'makes',
#   'things',
#   'never',
#   'said',
#   'boring',
#   'interviews',
#   'column.',
#   'neurotic',
#   'dope!'],
#  ['.@cnn',
#   'doesnt',
#   'get',
#   'it,',
#   'thats',
#   'ratings',
#   'low',
#   'getting',
#   'worse.',
#   'boring',
#   'antitrump',
#   'panelists,',
#   'mostly',
#   'losers',
#   'life!'],
#  ['never',
#   'met',
#   'former',
#   'defense',
#   'secretary',
#   'robert',
#   'gates.',
#   'knows',
#   'nothing',
#   'me.',
#   'look',
#   'results',
#   'guidance',
#   'total',
#   'disaster!'],
#  ['crooked',
#   'hillary',
#   'wants',
#   'take',
#   '2nd',
#   'amendment',
#   'rights',
#   'away.',
#   'guns',
#   'taken',
#   'heavily',
#   'armed',
#   'secret',
#   'service',
#   'detail?',
#   'maybe',
#   'not!'],
#  ['thoughts',
#   'prayers',
#   'go',
#   '@phillypolice',
#   '@penn',
#   'police',
#   'officers',
#   'philadelphia.http//abc7news.com/news/2policeofficersshotinwestphiladelphiasuspectdead/1515355/?utmsourcedlvr.itutmmediumtwitter'],
#  ['trumps',
#   'birther',
#   'event',
#   'greatest',
#   'trick',
#   'hes',
#   'ever',
#   'pulledhttp//wapo.st/2cqoaqc'],
#  ['arrived',
#   'texas',
#   'informed',
#   'two',
#   '@fortworthpd',
#   'officers',
#   'shot.',
#   'thoughts',
#   'prayers',
#   'them.'],
#  ['leaving',
#   'miami',
#   'houston,',
#   'oklahoma',
#   'colorado.',
#   'miami',
#   'crowd',
#   'fantastic!'],
#  ['great',
#   'parade',
#   'villages',
#   'love',
#   'all.',
#   '#maga.',
#   'thank',
#   'incredible',
#   'supporti',
#   'forget!'],
#  ['truly',
#   'honored',
#   'grateful',
#   'receiving',
#   'much',
#   'support',
#   'american',
#   'heroes...http//bit.ly/2cshfxf'],
#  ['going',
#   'brand',
#   'new',
#   'international,',
#   'hotel',
#   'd.c.',
#   'major',
#   'statement.'],
#  ['instead',
#   'driving',
#   'jobs',
#   'wealth',
#   'away,',
#   'america',
#   'become',
#   'worlds',
#   'great',
#   'magnet',
#   'innovation',
#   'job',
#   'creation!'],
#  ['thank',
#   'law',
#   'enforcement',
#   'officers',
#   'across',
#   'america!',
#   '#lesm',
#   '#maga',
#   'https//instagram.com/p/bkxdnpcdzkx/'],
#  ['never',
#   'fan',
#   'colin',
#   'powell',
#   'weak',
#   'understanding',
#   'weapons',
#   'mass',
#   'destruction',
#   'iraq',
#   'disaster.',
#   'much',
#   'better!'],
#  ['great',
#   'poll',
#   'nevada',
#   'thank',
#   'you!',
#   'see',
#   'soon.',
#   '#maga',
#   '#americafirsthttp//www.donaldjtrump.com'],
#  ['great',
#   'evening',
#   'canton,',
#   'ohiothank',
#   'you!',
#   'going',
#   'make',
#   'america',
#   'great',
#   'again!',
#   'join',
#   'us',
#   'http//www.donaldjtrump.com'],
#  ['thank',
#   'ohio!',
#   'landed',
#   'canton',
#   'rally',
#   'civic',
#   'center.',
#   'join',
#   '7pm',
#   'https//www.donaldjtrump.com/schedule/register/cantonoh/'],
#  ['thank',
#   'florida',
#   'cant',
#   'wait',
#   'see',
#   'friday',
#   'miami!',
#   'join',
#   'mehttp//bit.ly/2ciuuromiami'],
#  ['great', 'poll', 'florida', 'thank', 'you!', '#imwithyou', '#americafirst'],
#  ['thank', 'ohio', 'see', 'tonight!'],
#  ['russia',
#   'took',
#   'crimea',
#   'socalled',
#   'obama',
#   'years.',
#   'wouldnt',
#   'know',
#   'obama',
#   'get',
#   'free',
#   'pass?'],
#  ['isnt',
#   'president',
#   'obama',
#   'working',
#   'instead',
#   'campaigning',
#   'hillary',
#   'clinton?'],
#  ['got',
#   'back',
#   'asheville,',
#   'north',
#   'carolina,',
#   'massive',
#   'rally.',
#   'spirit',
#   'crowd',
#   'unbelievable.',
#   'thank',
#   'you!',
#   '#maga'],
#  ['stopped',
#   '@trumpdc',
#   'thank',
#   'tremendous',
#   'men',
#   'women',
#   'hard',
#   'work!'],
#  ['seriously',
#   'failing',
#   '@nytimes,',
#   'despite',
#   'much',
#   'winning',
#   'poll',
#   'numbers',
#   'soon',
#   'put',
#   'first',
#   'place,',
#   'writes',
#   'dishonest',
#   'hits!'],
#  ['hillary',
#   'clinton',
#   '47',
#   'moment.',
#   'terrible',
#   'thing',
#   'said',
#   'many',
#   'great',
#   'americans!'],
#  ['hillary',
#   'said',
#   'horrible',
#   'things',
#   'supporters,',
#   'many',
#   'supporters',
#   'never',
#   'vote',
#   'me,',
#   'still',
#   'respect',
#   'all!'],
#  ['really',
#   'sad',
#   'republicans',
#   'would',
#   'allow',
#   'used',
#   'clinton',
#   'ad.',
#   'lindsey',
#   'graham,',
#   'romney,',
#   'flake,',
#   'sass.',
#   'supreme',
#   'court,',
#   'remember!'],
#  ['wow,',
#   'hillary',
#   'clinton',
#   'insulting',
#   'supporters,',
#   'millions',
#   'amazing,',
#   'hard',
#   'working',
#   'people.',
#   'think',
#   'cost',
#   'polls!'],
#  ['missouri',
#   'today',
#   'melania',
#   'funeral',
#   'wonderful',
#   'truly',
#   'respected',
#   'woman,',
#   'phyllis',
#   's!'],
#  ['thank',
#   'ohio.',
#   'together,',
#   'make',
#   'america',
#   'great',
#   'again!http//www.donaldjtrump.com'],
#  ['great',
#   'honor',
#   'endorsed',
#   'popular',
#   'successful',
#   '@govgilmore',
#   'va.',
#   'state',
#   'much',
#   'want',
#   'winthx',
#   'jim!'],
#  ['make', 'america', 'great', 'again!#americafirst', '#imwithyou'],
#  ['.@cnn',
#   'unwatchable.',
#   'news',
#   'fiction.',
#   'theyare',
#   'disgrace',
#   'broadcasting',
#   'industry',
#   'arm',
#   'clinton',
#   'campaign.'],
#  ['documentary',
#   '@cnn',
#   'aired',
#   'total',
#   'waste',
#   'time.',
#   'dont',
#   'even',
#   'know',
#   'many',
#   'people',
#   'spoke',
#   'me.',
#   'joke!'],
#  ['final',
#   'poll',
#   'results',
#   'nbc',
#   'last',
#   'nights',
#   'commanderinchief',
#   'forum.',
#   'thank',
#   'you!',
#   '#imwithyou',
#   '#maga'],
#  ['wasnt',
#   'matt',
#   'lauer',
#   'hurt',
#   'hillary',
#   'last',
#   'night.',
#   'dumb',
#   'answer',
#   'emails',
#   'veteran',
#   'said',
#   'jail.'],
#  ['poll',
#   'results',
#   'last',
#   'nights',
#   'commanderinchief',
#   'forum.',
#   '#americafirst',
#   '#trumptrain'],
#  ['hillary',
#   'clinton',
#   'answered',
#   'email',
#   'questions',
#   'differently',
#   'last',
#   'night',
#   'past.',
#   'totally',
#   'confused.',
#   'unfit',
#   'serve',
#   '#potus.'],
#  ['hillary',
#   'gave',
#   'disastrous',
#   'news',
#   'conference',
#   'tarmac',
#   'make',
#   'poor',
#   'performance',
#   'last',
#   'night.',
#   'shes',
#   'decimated',
#   'media!'],
#  ['rough', 'night', 'hillary', 'clinton', 'abc', 'news.'],
#  ['thank', 'america', 'great', '#commanderinchiefforum', 'polls!'],
#  ['thank',
#   'fantastic',
#   'veterans.',
#   'reviews',
#   'polls',
#   'almost',
#   'everyone',
#   'commanderinchief',
#   'presentation',
#   'great.',
#   'nice!'],
#  ['thank',
#   'peter',
#   'elected,',
#   'think',
#   'big',
#   'country',
#   'never',
#   'let',
#   'american',
#   'people',
#   'down!',
#   '#americafirsthttps//www.washingtonpost.com/opinions/peterthieltrumphastaughtusthisyearsmostimportantpoliticallesson/2016/09/06/84df8182738c11e68149b8d05321db62story.html?postshare541473247265202tidsstw'],
#  ['wow',
#   'thank',
#   'pensacola,',
#   'fl.',
#   'see',
#   'friday',
#   '7pm',
#   'join',
#   'me!http//bit.ly/2ciou6wflorida'],
#  ['leads',
#   'hillary',
#   'clinton',
#   '19',
#   'points',
#   'among',
#   'military,',
#   'veteran',
#   'voters',
#   'poll',
#   '#americafirst',
#   '#magahttp//m.washingtontimes.com/news/2016/sep/7/donaldtrumpleadshillaryclinton19pointsamong/'],
#  ['thank',
#   'amazing',
#   'military',
#   'families,',
#   'service',
#   'members,',
#   'veterans.',
#   '#imwithyou'],
#  ['thank', 'you!', '#votetrump', '#imwithyou'],
#  ['mainstream',
#   'media',
#   'never',
#   'covered',
#   'hillarys',
#   'massive',
#   'hackingor',
#   'coughing',
#   'attack,',
#   'yet',
#   '#1',
#   'trending.',
#   'whats',
#   'up?'],
#  ['thank', 'you!', '#americafirst'],
#  ['china',
#   'wouldnt',
#   'provide',
#   'red',
#   'carpet',
#   'stairway',
#   'air',
#   'force',
#   'one',
#   'philippines',
#   'president',
#   'calls',
#   'obama',
#   'son',
#   'whore.',
#   'terrible!'],
#  ['truly',
#   'great',
#   'phyllis',
#   'schlafly,',
#   'honored',
#   'strong',
#   'endorsement',
#   'president,',
#   'passed',
#   'away',
#   '92.',
#   'special!'],
#  ['heading', 'youngstown,', 'ohio', 'great', 'polls.', '#americafirst'],
#  ['believe',
#   'chinese',
#   'would',
#   'give',
#   'obama',
#   'proper',
#   'stairway',
#   'get',
#   'plane',
#   'fight',
#   'tarmac!http//nypost.com/2016/09/03/thisisourcountrytempersflareasobamaarrivesinchina/'],
#  ['president',
#   'obama',
#   'putin',
#   'fail',
#   'reach',
#   'deal',
#   'syria',
#   'else',
#   'new?',
#   'obama',
#   'natural',
#   'deal',
#   'maker.',
#   'makes',
#   'bad',
#   'deals!'],
#  ['lyin',
#   'hillary',
#   'clinton',
#   'told',
#   'fbi',
#   'know',
#   'c',
#   'markings',
#   'documents',
#   'stood',
#   'classified.',
#   'happening?'],
#  ['africanamerican',
#   'community',
#   'democrats',
#   'failed',
#   'fifty',
#   'years,',
#   'high',
#   'crime,',
#   'poor',
#   'schools,',
#   'jobs.',
#   'fix',
#   'it,',
#   'vote'],
#  ['polls',
#   'close',
#   'crooked',
#   'hillary',
#   'getting',
#   'bed',
#   'campaign',
#   'tomorrow.why',
#   'hammer',
#   '13',
#   'devices',
#   'acidwash',
#   'emails?'],
#  ['wow,',
#   'failing',
#   '@nytimes',
#   'reported',
#   'properly',
#   'crookeds',
#   'fbi',
#   'release.',
#   'back',
#   'pack',
#   'longer',
#   'credible',
#   'source'],
#  ['.@cnn',
#   'disgusting',
#   'bias,',
#   'hard',
#   'time',
#   'promoting',
#   'crooked',
#   'hillary',
#   'light',
#   'new',
#   'email',
#   'scandals.'],
#  ['great',
#   'visit',
#   'detroit',
#   'church,',
#   'fantastic',
#   'reception,',
#   '@cnn',
#   'talks',
#   'small',
#   'protest',
#   'outside.',
#   'inside',
#   'large',
#   'wonderful',
#   'crowd!'],
#  ['thank',
#   'great',
#   'faith',
#   'ministries',
#   'international,',
#   'bishop',
#   'wayne',
#   't.',
#   'jackson,',
#   'detroit!http//www.snappytv.com/tc/2727709'],
#  ['great',
#   'new',
#   'poll',
#   'iowa',
#   'thank',
#   'you!#makeamericagreatagain',
#   '#imwithyou'],
#  ['visited',
#   'tower',
#   'campaign',
#   'headquarters',
#   'last',
#   'night,',
#   'returning',
#   'ohio',
#   'arizona,',
#   'packed',
#   'great',
#   'pros',
#   'win!'],
#  ['people',
#   'surprised',
#   'ground',
#   'game',
#   'nov.',
#   '8.',
#   'army',
#   'volunteers',
#   'people',
#   'great',
#   'spirit!',
#   'want',
#   '#maga!'],
#  ['promising',
#   'new',
#   'legacy',
#   'america.',
#   'going',
#   'create',
#   'new',
#   'american',
#   'future.',
#   'thank',
#   'ohio!',
#   '#imwithyou'],
#  ['poll', 'numbers', 'way', 'making', 'big', 'progress!'],
#  ['thank',
#   '@foxandfriends',
#   'great',
#   'review',
#   'speech',
#   'immigration',
#   'last',
#   'night.',
#   'thank',
#   'also',
#   'great',
#   'people',
#   'arizona!'],
#  ['mexico', 'pay', 'wall!'],
#  ['administration,',
#   'called',
#   '#americafirst!',
#   '#imwithyouhttp//www.snappytv.com/tc/2711850'],
#  ['great',
#   'trip',
#   'mexico',
#   'today',
#   'wonderful',
#   'leadership',
#   'high',
#   'quality',
#   'people!',
#   'look',
#   'forward',
#   'next',
#   'meeting.'],
#  ['hillary',
#   'clinton',
#   'didnt',
#   'go',
#   'louisiana,',
#   'didnt',
#   'go',
#   'mexico.',
#   'doesnt',
#   'drive',
#   'stamina',
#   'make',
#   'america',
#   'great',
#   'again!'],
#  ['former',
#   'president',
#   'vicente',
#   'fox,',
#   'railing',
#   'visit',
#   'mexico',
#   'today,',
#   'also',
#   'invited',
#   'apologized',
#   'using',
#   'f',
#   'bomb.'],
#  ['thank',
#   'washington!',
#   'together,',
#   'make',
#   'america',
#   'safe',
#   'great',
#   'again!',
#   '#imwithyou',
#   '#americafirst'],
#  ['accepted',
#   'invitation',
#   'president',
#   'enrique',
#   'pena',
#   'nieto,',
#   'mexico,',
#   'look',
#   'much',
#   'forward',
#   'meeting',
#   'tomorrow.'],
#  ['thank', 'north', 'carolina!', '#maga'],
#  ['day',
#   'one',
#   'said',
#   'going',
#   'build',
#   'great',
#   'wall',
#   'southern',
#   'border,',
#   'much',
#   'more.',
#   'stop',
#   'illegal',
#   'immigration.',
#   'watch',
#   'wednesday!'],
#  ['repeal', 'replace', 'horrible', 'disaster', 'known', '#obamacare!'],
#  ['africanamericans',
#   'seeing',
#   'bad',
#   'job',
#   'hillary',
#   'type',
#   'policy',
#   'management',
#   'done',
#   'innercities,',
#   'want',
#   'trump!'],
#  ['anyone',
#   'know',
#   'crooked',
#   'hillary,',
#   'tried',
#   'hard,',
#   'unable',
#   'pass',
#   'bar',
#   'exams',
#   'washington',
#   'd.c.',
#   'forced',
#   'go',
#   'elsewhere'],
#  ['making',
#   'major',
#   'speech',
#   'illegal',
#   'immigration',
#   'wednesday',
#   'great',
#   'state',
#   'arizona.',
#   'big',
#   'crowds,',
#   'looking',
#   'larger',
#   'venue.'],
#  ['think',
#   'candidates,',
#   'crooked',
#   'hillary',
#   'myself,',
#   'release',
#   'detailed',
#   'medical',
#   'records.',
#   'problem',
#   'so!',
#   'hillary?'],
#  ['today',
#   '53rd',
#   'anniversary',
#   'march',
#   'washington',
#   'today',
#   'honor',
#   'enduring',
#   'fight',
#   'justice,',
#   'equality',
#   'opportunity.'],
#  ['national',
#   'debt',
#   'january',
#   '2009',
#   '10.6',
#   'trillionaugust',
#   '2016',
#   '19.4',
#   'trillion'],
#  ['honor',
#   'amazing',
#   'root',
#   'family',
#   'join',
#   'iowa.',
#   'inspired',
#   'courage',
#   'bravery.https//amp.twimg.com/v/d96463a2c8f542a38865065ba39beb30'],
#  ['condolences',
#   'dwyane',
#   'wade',
#   'family,',
#   'loss',
#   'nykea',
#   'aldridge.',
#   'thoughts',
#   'prayers.'],
#  ['dwyane',
#   'wades',
#   'cousin',
#   'shot',
#   'killed',
#   'walking',
#   'baby',
#   'chicago.',
#   'saying.',
#   'africanamericans',
#   'vote',
#   'trump!'],
#  ['@diamondandsilk',
#   'crooked',
#   'hillary',
#   'getting',
#   'desperate.',
#   'tv',
#   'bashing',
#   'trump.',
#   '@cnn,',
#   'forgot',
#   'said',
#   'kkk',
#   'member',
#   'mentor.'],
#  ['heroin',
#   'overdoses',
#   'taking',
#   'children',
#   'others',
#   'midwest.',
#   'coming',
#   'southern',
#   'border.',
#   'need',
#   'strong',
#   'border',
#   'wall!'],
#  ['new',
#   'polls',
#   'join',
#   'movement',
#   'today.http//www.donaldjtrump.com',
#   '#imwithyou'],
#  ['phoenix,',
#   'arizona',
#   'wednesday.',
#   'changing',
#   'venue',
#   'much',
#   'larger',
#   'one.',
#   'demand',
#   'unreal.',
#   'polls',
#   'looking',
#   'great!',
#   '#imwithyou'],
#  ['quickly',
#   'people',
#   'forget',
#   'crooked',
#   'hillary',
#   'called',
#   'africanamerican',
#   'youth',
#   'super',
#   'predators',
#   'apologized?'],
#  ['proud',
#   'brought',
#   'subject',
#   'illegal',
#   'immigration',
#   'back',
#   'discussion.',
#   'big',
#   'problem',
#   'countryi',
#   'solve'],
#  ['africanamericans',
#   'hispanics',
#   'lose',
#   'going',
#   'me.',
#   'look',
#   'poverty,',
#   'crime',
#   'educational',
#   'statistics.',
#   'fix',
#   'it!'],
#  ['crooked',
#   'hillary',
#   'never',
#   'able',
#   'solve',
#   'problems',
#   'poverty,',
#   'education',
#   'safety',
#   'within',
#   'africanamerican',
#   'hispanic',
#   'communities'],
#  ['hillary',
#   'clinton',
#   'needs',
#   'address',
#   'racist',
#   'undertones',
#   '2008',
#   'campaign.',
#   '#flashbackfriday'],
#  ['hillary',
#   'clinton',
#   'knows',
#   'make',
#   'speech',
#   'hit',
#   'me.',
#   'policy,',
#   'always',
#   'short',
#   'stamina.',
#   'media',
#   'gives',
#   'pass!'],
#  ['hrc',
#   'using',
#   'oldest',
#   'play',
#   'dem',
#   'playbook',
#   'policies',
#   'fail,',
#   'left',
#   'w/this',
#   'one',
#   'tired',
#   'argument!http//www.snappytv.com/tc/2673821'],
#  ['hillary',
#   'clinton',
#   'using',
#   'racebaiting',
#   'try',
#   'get',
#   'africanamerican',
#   'voters',
#   'know',
#   'talk',
#   'action!'],
#  ['hillary',
#   'clintons',
#   'short',
#   'speech',
#   'pandering',
#   'worst',
#   'instincts',
#   'society.',
#   'ashamed',
#   'herself!'],
#  ['watched',
#   'recap',
#   '#crookedhillarys',
#   'speech.',
#   'short',
#   'lies.',
#   'one',
#   'fearmongering!'],
#  ['many',
#   'africanamerican',
#   'community',
#   'badly,',
#   'poverty',
#   'crime',
#   'way',
#   'up,',
#   'employment',
#   'jobs',
#   'way',
#   'fix',
#   'it,',
#   'promise'],
#  ['poll',
#   'numbers',
#   'starting',
#   'look',
#   'good.',
#   'leading',
#   'florida',
#   '@cnn',
#   'arizona',
#   'big',
#   'jump',
#   'utah.',
#   'numbers',
#   'rising,',
#   'national',
#   'way',
#   'up.',
#   'wow!'],
#  ['thoughts', 'prayers', 'great', 'people', 'indiana.', 'prevail!'],
#  ['great',
#   'governor',
#   '@mikepence',
#   'indiana',
#   'help',
#   'lead',
#   'relief',
#   'efforts',
#   'tornadoes',
#   'struck.',
#   'true',
#   'leadership.'],
#  ['great',
#   'new',
#   'poll',
#   'florida',
#   'thank',
#   'you!',
#   '#makeamericagreatagain'],
#  ['thoughts',
#   'prayers',
#   'victims',
#   'families',
#   'affected',
#   'two',
#   'powerful',
#   'earthquakes',
#   'italy',
#   'myanmar.'],
#  ['thank', 'travis', 'county,', 'texas!#makeamericagreatagain'],
#  ['austin,',
#   'texas',
#   'amazing',
#   'border',
#   'patrol',
#   'agents.',
#   'let',
#   'down!',
#   'https//instagram.com/p/bjdya79dxof/'],
#  ['president',
#   'obama',
#   'gone',
#   'louisiana',
#   'days',
#   'ago,',
#   'instead',
#   'golfing.',
#   'little,',
#   'late!'],
#  ['reported',
#   'virtually',
#   'everyone,',
#   'fact,',
#   'media',
#   'pile',
#   'worst',
#   'american',
#   'political',
#   'history!'],
#  ['.@anncoulters',
#   'new',
#   'book,',
#   'trust,',
#   'comes',
#   'tomorrow.',
#   'people',
#   'saying',
#   'terrific',
#   'knowing',
#   'ann',
#   'sure',
#   'is!'],
#  ['leaving',
#   'akron,',
#   'ohio,',
#   'packed',
#   'rally.',
#   'amazing',
#   'people!',
#   'going',
#   'texas.'],
#  ['great',
#   'meeting',
#   'active',
#   'retired',
#   'law',
#   'enforcement',
#   'officers',
#   'fraternal',
#   'order',
#   'police',
#   'lodge',
#   'akron,',
#   'ohio.'],
#  ['day,',
#   'things',
#   'calm',
#   'down,',
#   'ill',
#   'tell',
#   'real',
#   'story',
#   '@joenbc',
#   'insecure',
#   'longtime',
#   'girlfriend,',
#   '@morningmika.',
#   'two',
#   'clowns!'],
#  ['crooked',
#   'hillary',
#   'flooding',
#   'airwaves',
#   'false',
#   'misleading',
#   'ads',
#   'paid',
#   'bosses',
#   'wall',
#   'street.',
#   'media',
#   'protecting',
#   'her!'],
#  ['drawing',
#   'big',
#   'enthusiastic',
#   'crowds,',
#   'media',
#   'refuses',
#   'show',
#   'discuss',
#   'them.',
#   'something',
#   'big',
#   'happening!'],
#  ['together,',
#   'going',
#   'make',
#   'america',
#   'safe',
#   'great',
#   'again!http//www.breitbart.com/2016presidentialrace/2016/08/20/latimespolltrumptakeshalfpointleadclinton/'],
#  ['bring',
#   'america',
#   'together',
#   'one',
#   'country',
#   'united',
#   'americans',
#   'common',
#   'purpose',
#   'common',
#   'dreams.',
#   '#maga'],
#  ['@catonglass',
#   '200,000',
#   'new',
#   'followers',
#   '10,800,000',
#   '11,000,000,',
#   'last',
#   'ten',
#   'days',
#   'so!',
#   '#maga',
#   '#alwaystrump'],
#  ['.@franklingraham',
#   '@billynungesser',
#   '@samaritanspurse',
#   'humbled',
#   'time',
#   'w/',
#   'you.',
#   'thoughts',
#   'prayers.'],
#  ['one',
#   'nation.',
#   'one',
#   'hurts,',
#   'hurt.',
#   'must',
#   'work',
#   'togetherto',
#   'lift',
#   'up.#standwithlouisiana'],
#  ['#whereshillary?', 'sleeping!!!!!'],
#  ['thank',
#   'michigan.',
#   'movement.',
#   'going',
#   'make',
#   'america',
#   'safe',
#   'great',
#   'again!',
#   '#trumppence16'],
#  ['thank',
#   'everyone',
#   'nice',
#   'comments,',
#   'twitter,',
#   'pundits',
#   'otherwise',
#   'speech',
#   'last',
#   'night.'],
#  ['soon', 'calling', 'mr.', 'brexit!'],
#  ['going',
#   'make',
#   'government',
#   'people',
#   'again!#makeamericagreatagain',
#   '#imwithyouhttps//amp.twimg.com/v/4586e62b3a35479da65df984df338175'],
#  ['repeal',
#   'replace',
#   '#obamacare,',
#   'caused',
#   'soaring',
#   'doubledigit',
#   'premium',
#   'increases.',
#   'disaster!https//amp.twimg.com/v/ddb1eaf1bdc544b3b090dc20494568f7'],
#  ['vote',
#   'hillary',
#   'clinton',
#   'vote',
#   'another',
#   'generation',
#   'poverty,',
#   'high',
#   'crime,',
#   'lost',
#   'opportunities.',
#   '#imwithyouhttps//amp.twimg.com/v/d4fc15a4b04b48cc85a8fbdf61211602'],
#  ['another',
#   'health',
#   'insurer',
#   'pulling',
#   'back',
#   'due',
#   'persistent',
#   'financial',
#   'losses',
#   '#obamacare',
#   'plans.',
#   'beginning!http//www.nbcnews.com/business/businessnews/aetnapullsbackobamacarehealthinsuranceplans2017n631656'],
#  ['clinton',
#   'refugee',
#   'plan',
#   'could',
#   'bring',
#   '620,000',
#   'refugees',
#   'first',
#   'term',
#   'lifetime',
#   'cost',
#   '400',
#   'billion.',
#   'http//www.sessions.senate.gov/public/index.cfm/2016/6/clintonrefugeeplancouldbringin620000refugeesinfirsttermatlifetimecostofover400billion'],
#  ['certain',
#   'republicans',
#   'lost',
#   'would',
#   'rather',
#   'save',
#   'face',
#   'fighting',
#   'see',
#   'u.s.supreme',
#   'court',
#   'get',
#   'proper',
#   'appointments.',
#   'sad!'],
#  ['stay',
#   'message',
#   'chant.',
#   'always',
#   'trade,',
#   'jobs,',
#   'military,',
#   'vets,',
#   '2nd',
#   'a,',
#   'repeal',
#   'ocare,',
#   'borders,',
#   'etc',
#   'media',
#   'misrepresents!'],
#  ['always',
#   'personremain',
#   'true',
#   'self.the',
#   'media',
#   'wants',
#   'change',
#   'would',
#   'dishonest',
#   'supporters',
#   'so!'],
#  ['freedom',
#   'press',
#   'newspapers',
#   'others',
#   'allowed',
#   'say',
#   'write',
#   'whatever',
#   'want',
#   'even',
#   'completely',
#   'false!'],
#  ['fighting',
#   'crooked',
#   'hillary,',
#   'fighting',
#   'dishonest',
#   'corrupt',
#   'media',
#   'government',
#   'protection',
#   'process.',
#   'people',
#   'get',
#   'it!'],
#  ['crooked',
#   'hillary',
#   'clinton',
#   'protected',
#   'media.',
#   'talented',
#   'person',
#   'politician.',
#   'dishonest',
#   'media',
#   'refuses',
#   'expose!'],
#  ['rallies',
#   'covered',
#   'properly',
#   'media.',
#   'never',
#   'discuss',
#   'real',
#   'message',
#   'never',
#   'show',
#   'crowd',
#   'size',
#   'enthusiasm.'],
#  ['disgusting',
#   'corrupt',
#   'media',
#   'covered',
#   'honestly',
#   'didnt',
#   'put',
#   'false',
#   'meaning',
#   'words',
#   'say,',
#   'would',
#   'beating',
#   'hillary',
#   '20'],
#  ['failing',
#   '@nytimes,',
#   'never',
#   'spoke',
#   'me,',
#   'keeps',
#   'saying',
#   'saying',
#   'advisers',
#   'change.',
#   'false,',
#   'amnever',
#   'said'],
#  ['failing',
#   '@nytimes',
#   'talks',
#   'anonymous',
#   'sources',
#   'meetings',
#   'never',
#   'happened.',
#   'reporting',
#   'fiction.',
#   'media',
#   'protects',
#   'hillary!'],
#  ['confirmation',
#   'one',
#   'reason',
#   'crooked',
#   'h',
#   'wanted',
#   'sure',
#   'nobody',
#   'saw',
#   'emails',
#   'payforplay.',
#   'run',
#   'pres.'],
#  ['truly',
#   'enjoying',
#   'running',
#   'president.',
#   'people',
#   'country',
#   'amazing',
#   'great',
#   'numbers',
#   'november',
#   '8th!'],
#  ['failing',
#   '@nytimes',
#   'become',
#   'newspaper',
#   'fiction.',
#   'stories',
#   'always',
#   'quote',
#   'nonexistent',
#   'unnamed',
#   'sources.',
#   'dishonest!'],
#  ['thank', 'erie,', 'pennsylvania!', 'together', '#makeamericagreatagain!'],
#  ['isis',
#   'gained',
#   'tremendous',
#   'strength',
#   'hillary',
#   'clintons',
#   'term',
#   'secretary',
#   'state.',
#   'dishonest',
#   'media',
#   'report',
#   'facts!'],
#  ['love',
#   'watching',
#   'poor,',
#   'pathetic',
#   'people',
#   'pundits',
#   'television',
#   'working',
#   'hard',
#   'seriously',
#   'try',
#   'figure',
#   'out.',
#   'cant!'],
#  ['massive',
#   'tax',
#   'increase',
#   'necessary',
#   'fund',
#   'crooked',
#   'hillary',
#   'clintons',
#   'agenda.',
#   'terrible',
#   'boring',
#   'rollout',
#   'yesterday!'],
#  ['ratings',
#   'challenged',
#   '@cnn',
#   'reports',
#   'seriously',
#   'call',
#   'president',
#   'obama',
#   'clinton',
#   'founder',
#   'isis,',
#   'mvp.',
#   'dont',
#   'get',
#   'sarcasm?'],
#  ['@elsolarverde',
#   'corrupt',
#   'media',
#   'creats',
#   'controversy',
#   'avoid',
#   'issues',
#   'hillaryclinton'],
#  ['surprise.',
#   'constant',
#   'phony',
#   'reporting',
#   'failing',
#   '@cnn',
#   'turns',
#   'everyone',
#   'off.',
#   'american',
#   'people',
#   'get',
#   'it!',
#   'http//www.adweek.com/tvnewser/scoreboardtuesdayaugust9/301887'],
#  ['thank', 'fort', 'lauderdale,', 'florida.', '#makeamericagreatagain'],
#  ['great',
#   'job',
#   'today',
#   'nypd',
#   'protecting',
#   'people',
#   'saving',
#   'climber.'],
#  ['reuters',
#   'announced',
#   'secret',
#   'service',
#   'never',
#   'spoke',
#   'campaign.',
#   'made',
#   'story',
#   '@cnn',
#   'hoax.',
#   'totally',
#   'dishonest.'],
#  ['thoughts',
#   'prayers',
#   'two',
#   'police',
#   'officers',
#   'shot',
#   'sebastian',
#   'county,',
#   'arkansas.',
#   '#lesm'],
#  ['.@dbongino',
#   'fantastic',
#   'defending',
#   'second',
#   'amendment',
#   'last',
#   'night',
#   '@cnn.',
#   'lemon',
#   'lightweight',
#   'dumb',
#   'rock'],
#  ['media',
#   'desperate',
#   'distract',
#   'clintons',
#   'anti2a',
#   'stance.',
#   'said',
#   'pro2a',
#   'citizens',
#   'must',
#   'organize',
#   'get',
#   'vote',
#   'save',
#   'constitution!'],
#  ['media',
#   'going',
#   'talk',
#   'hillarys',
#   'policies',
#   'gotten',
#   'people',
#   'killed,',
#   'like',
#   'libya,',
#   'open',
#   'borders,',
#   'maybe',
#   'emails?'],
#  ['thank', 'wilmington,', 'north', 'carolina!#makeamericagreatagain'],
#  ['running',
#   'washington',
#   'insiders,',
#   'like',
#   'republican',
#   'primaries.',
#   'people',
#   'made',
#   'u.s.',
#   'mess!'],
#  ['detroit',
#   'today',
#   'wonderful.',
#   'quick',
#   'stop',
#   'ohio',
#   'meet',
#   'great',
#   'supporters.',
#   'got',
#   'back',
#   'home!'],
#  ['many',
#   'people',
#   'saying',
#   'iranians',
#   'killed',
#   'scientist',
#   'helped',
#   'u.s.',
#   'hillary',
#   'clintons',
#   'hacked',
#   'emails.'],
#  ['thank', 'newt!https//twitter.com/newtgingrich/status/762739520567738368'],
#  ['#icymi',
#   'media',
#   'apologize',
#   'trump?http//www.thegatewaypundit.com/2016/08/willmediaapologizetrumpmothercryingbabyrallyspeaks/'],
#  ['michael',
#   'morell,',
#   'lightweight',
#   'former',
#   'acting',
#   'director',
#   'c.i.a.,',
#   'man',
#   'made',
#   'serious',
#   'bad',
#   'calls,',
#   'total',
#   'clinton',
#   'flunky!'],
#  ['media',
#   'going',
#   'crazy.',
#   'totally',
#   'distort',
#   'many',
#   'things',
#   'purpose.',
#   'crimea,',
#   'nuclear,',
#   'baby',
#   'much',
#   'more.',
#   'dishonest!'],
#  ['see',
#   'mayor',
#   'stephanie',
#   'rawlingsblake',
#   'baltimore',
#   'pushing',
#   'crooked',
#   'hard.',
#   'look',
#   'job',
#   'done',
#   'baltimore.',
#   'joke!'],
#  ['.@larrykudlow',
#   'middleclass',
#   'growth',
#   'candidatehttp//www.cnbc.com/2016/08/06/kudlowdonaldtrumpisthemiddleclassgrowthcandidate.html'],
#  ['running',
#   'crooked',
#   'hillary',
#   'clinton,',
#   'running',
#   'dishonest',
#   'totally',
#   'biased',
#   'media',
#   'win!'],
#  ['heading',
#   'new',
#   'hampshire',
#   'talking',
#   'hillary',
#   'saying',
#   'brain',
#   'short',
#   'circuited,',
#   'things!'],
#  ['anybody',
#   'whose',
#   'mind',
#   'short',
#   'circuits',
#   'fit',
#   'president!',
#   'look',
#   'word',
#   'brainwashed.'],
#  ['crooked',
#   'hillary',
#   'said',
#   'loudly,',
#   'world',
#   'see,',
#   'short',
#   'circuited',
#   'answering',
#   'question',
#   'emails.',
#   'dangerous!'],
#  ['hillary',
#   'clinton',
#   'badly',
#   'criticized',
#   'poor',
#   'performance',
#   'answering',
#   'questions.',
#   'let',
#   'us',
#   'see',
#   'happens!'],
#  ['right',
#   'violent',
#   'crime',
#   'rise',
#   'major',
#   'citieshttps//www.washingtonpost.com/opinions/trumpisrightaboutviolentcrimeitsontheriseinmajorcities/2016/08/05/3cf6b55e5b1111e69aee8075993d73a2story.html'],
#  ['thank',
#   'green',
#   'bay,',
#   'wisconsin!',
#   'governor',
#   '@mikepence',
#   'back',
#   'soon.',
#   '#trumppence16',
#   '#maga'],
#  ['dont',
#   'let',
#   'hillary',
#   'clinton',
#   'again!#trumppence16https//amp.twimg.com/v/42d9c3c3e9244a5bb8a9540ec3d21654'],
#  ['plane',
#   'saw',
#   'television',
#   'hostage',
#   'plane',
#   'geneva,',
#   'switzerland,',
#   'plane',
#   'carrying',
#   '400',
#   'million',
#   'cash',
#   'going',
#   'iran!'],
#  ['president',
#   'obama',
#   'refuses',
#   'answer',
#   'question',
#   'iran',
#   'terror',
#   'funding.',
#   'wont',
#   'dodge',
#   'questions',
#   'president.',
#   'http//ntknetwork.com/obamaspends7minutesdodgingonwhetheriranwilluse400milliontofundterrorism/'],
#  ['obamas',
#   'disastrous',
#   'judgment',
#   'gave',
#   'us',
#   'isis,',
#   'rise',
#   'iran,',
#   'worst',
#   'economic',
#   'numbers',
#   'since',
#   'great',
#   'depression!'],
#  ['president', 'obama', 'ask', 'dnc', 'rigged', 'election', 'bernie.'],
#  ['happy',
#   '226th',
#   'birthday',
#   'united',
#   'states',
#   'coast',
#   'guard.',
#   'thank',
#   '@uscg!',
#   '#coastguardday'],
#  ['thank',
#   'amazing',
#   'law',
#   'enforcement',
#   'officers',
#   'today',
#   'daytona',
#   'beach,',
#   'florida!',
#   '#lesm',
#   '#maga'],
#  ['incompetent',
#   'secretary',
#   'state,',
#   'hillary',
#   'clinton,',
#   'one',
#   'started',
#   'talks',
#   'give',
#   '400',
#   'million',
#   'dollars,',
#   'cash,',
#   'iran.',
#   'scandal!'],
#  ['great',
#   'unity',
#   'campaign,',
#   'perhaps',
#   'greater',
#   'ever',
#   'before.',
#   'want',
#   'thank',
#   'everyone',
#   'tremendous',
#   'support.',
#   'beat',
#   'crooked',
#   'h!'],
#  ['president',
#   'obama',
#   'go',
#   'perhaps',
#   'worst',
#   'president',
#   'history',
#   'united',
#   'states!'],
#  ['washington',
#   'post',
#   'calls',
#   '#crookedhillary',
#   'really',
#   'is.',
#   'pathological',
#   'liar!',
#   'watch',
#   'nose',
#   'grow!'],
#  ['great',
#   'afternoon',
#   'ohio',
#   'great',
#   'evening',
#   'pennsylvania',
#   'departing',
#   'now.',
#   'see',
#   'tomorrow',
#   'virginia!'],
#  ['leaving',
#   'mechanicsburg,',
#   'pa.',
#   'incredible',
#   'crowd',
#   'enthusiastic!',
#   'back',
#   'soon.',
#   '#maga'],
#  ['cnn',
#   'segment',
#   'hillarys',
#   'plan',
#   'increase',
#   'syrian',
#   'refugees',
#   '550',
#   'much',
#   'cost?'],
#  ['hillary',
#   'clinton',
#   'raked',
#   'money',
#   'regimes',
#   'horribly',
#   'oppress',
#   'women',
#   'gays',
#   'refuses',
#   'speak',
#   'radical',
#   'islam.'],
#  ['hillary,',
#   'whose',
#   'decisions',
#   'led',
#   'deaths',
#   'many,',
#   'accepted',
#   'business',
#   'linked',
#   'isis.',
#   'silence',
#   'cnn.http//www.thegatewaypundit.com/2016/08/wikileakshillary/'],
#  ['crooked',
#   'hillary',
#   'clinton',
#   '100',
#   'owned',
#   'donors.',
#   '#imwithyou',
#   '#maga'],
#  ['thank', 'oklahoma', 'virginia!', '#makeamericagreatagain', '#imwithyou'],
#  ['people',
#   'believe',
#   'cnn',
#   'days',
#   'almost',
#   'little',
#   'believe',
#   'hillary....thats',
#   'really',
#   'saying',
#   'something!'],
#  ['cnn',
#   'send',
#   'cameras',
#   'border',
#   'show',
#   'massive',
#   'unreported',
#   'crisis',
#   'unfolding',
#   'worried',
#   'hurt',
#   'hillary?'],
#  ['see',
#   'stories',
#   'cnn',
#   'clinton',
#   'foundation',
#   'corruption',
#   'hillarys',
#   'payforplay',
#   'state',
#   'department?'],
#  ['cnn',
#   'soon',
#   'least',
#   'trusted',
#   'name',
#   'news',
#   'continue',
#   'press',
#   'shop',
#   'hillary',
#   'clinton.'],
#  ['story',
#   'mr.',
#   'khan,',
#   'place',
#   'interviews,',
#   'rather',
#   'radical',
#   'islamic',
#   'terrorism',
#   'u.s.',
#   'get',
#   'smart!'],
#  ['wow,',
#   'unbelievable',
#   'distorted,',
#   'onesided',
#   'biased',
#   'media',
#   'us.',
#   'failing',
#   '@nytimes',
#   'joke.',
#   '@cnn',
#   'laughable!'],
#  ['@realjameswoods',
#   'without',
#   'absolutely',
#   'owning',
#   'liberal',
#   'media,',
#   'hillaryclinton',
#   'wouldnt',
#   'stand',
#   'chance.',
#   '#voterfraud',
#   '#msm',
#   'hope.'],
#  ['dishonest',
#   'media',
#   'fawning',
#   'democratic',
#   'convention.',
#   'wonder',
#   'why,',
#   'then,',
#   'speech',
#   'millions',
#   'viewers',
#   'crooked',
#   'h?'],
#  ['viciously',
#   'attacked',
#   'mr.',
#   'khan',
#   'democratic',
#   'convention.',
#   'allowed',
#   'respond?',
#   'hillary',
#   'voted',
#   'iraq',
#   'war,',
#   'me!'],
#  ['captain',
#   'khan,',
#   'killed',
#   '12',
#   'years',
#   'ago,',
#   'hero,',
#   'radical',
#   'islamic',
#   'terror',
#   'weakness',
#   'leaders',
#   'eradicate',
#   'it!'],
#  ['nielson',
#   'media',
#   'research',
#   'final',
#   'numbers',
#   'acceptance',
#   'speech',
#   '32.2',
#   'million.',
#   'clinton',
#   '27.8',
#   'million.',
#   'thank',
#   'you!'],
#  ['thank',
#   'television',
#   'viewers',
#   'made',
#   'speech',
#   'republican',
#   'national',
#   'convention',
#   '#1',
#   'crooked',
#   'hillary',
#   'dems.'],
#  ['wow,',
#   'natos',
#   'top',
#   'commander',
#   'announced',
#   'agrees',
#   'alliance',
#   'members',
#   'must',
#   'pay',
#   'bills.',
#   'general',
#   'like!'],
#  ['crookeds',
#   'stop',
#   'johnstown,',
#   'pennsylvania,',
#   'jobs',
#   'absolutely',
#   'decimated',
#   'dumb',
#   'politicians,',
#   'drew',
#   'less',
#   '200',
#   'bill,',
#   'vp'],
#  ['#crookedhillary',
#   'obamas',
#   'third',
#   'term,',
#   'would',
#   'terrible',
#   'news',
#   'economic',
#   'growth',
#   'seen',
#   'below.'],
#  ['turned',
#   'meeting',
#   'charles',
#   'david',
#   'koch.',
#   'much',
#   'better',
#   'meet',
#   'puppets',
#   'politics,',
#   'much',
#   'better!'],
#  ['crooked',
#   'hillary',
#   'clinton',
#   'soft',
#   'crime,',
#   'supports',
#   'open',
#   'borders,',
#   'wants',
#   'massive',
#   'tax',
#   'hikes.',
#   'formula',
#   'disaster!'],
#  ['violent',
#   'crime',
#   'rising',
#   'across',
#   'united',
#   'states,',
#   'yet',
#   'dnc',
#   'convention',
#   'ignored',
#   'it.',
#   'crime',
#   'reduction',
#   'one',
#   'top',
#   'priorities.'],
#  ['american',
#   'homeownership',
#   'rate',
#   'q2',
#   '2016',
#   '62.9',
#   'lowest',
#   'rate',
#   '51yrs.',
#   'bring',
#   'back',
#   'american',
#   'dream!'],
#  ['@patrioticpepe',
#   'unite',
#   'america',
#   'fix',
#   'obamas',
#   'mistakes!!!',
#   '#trump2016'],
#  ['usual,',
#   'hillary',
#   'dems',
#   'trying',
#   'rig',
#   'debates',
#   '2',
#   'major',
#   'nfl',
#   'games.',
#   'last',
#   'time',
#   'w/',
#   'bernie.',
#   'unacceptable!'],
#  ['#crookedhillary', 'job', 'application'],
#  ['hillary',
#   'clinton',
#   'given',
#   'national',
#   'security',
#   'briefings',
#   'lose',
#   'cannon',
#   'extraordinarily',
#   'bad',
#   'judgement',
#   'insticts.'],
#  ['thank',
#   'amazing',
#   'law',
#   'enforcement',
#   'officers',
#   'colorado!#makeamericagreatagain',
#   '#lesm'],
#  ['bernie', 'sanders', 'really', 'thinks', 'crooked', 'hillary', 'clinton.'],
#  ['wow,',
#   'campaign',
#   'hearing',
#   'bernie',
#   'supporters',
#   'never',
#   'support',
#   'crooked',
#   'hillary.',
#   'sold',
#   'out,',
#   'v.p.',
#   'pick!'],
#  ['hillary',
#   'clintons',
#   'america',
#   'things',
#   'get',
#   'worse.',
#   '#trumppence16'],
#  ['crooked',
#   'hillary',
#   'said',
#   'couldnt',
#   'handle',
#   'rough',
#   'tumble',
#   'political',
#   'campaign.',
#   'really,i',
#   'beat',
#   '16',
#   'people',
#   'beating',
#   'her!'],
#  ['crooked',
#   'hillary',
#   'clinton',
#   'mentioned',
#   '22',
#   'times',
#   'long',
#   'boring',
#   'speech.',
#   'many',
#   'statements',
#   'lies',
#   'fabrications!'],
#  ['@anncoulter',
#   'believe',
#   'science',
#   'dem',
#   'code',
#   'shutting',
#   'coal',
#   'mines,',
#   'steel',
#   'plants',
#   'remaining',
#   'manufacturing'],
#  ['two',
#   'policemen',
#   'shot',
#   'san',
#   'diego,',
#   'one',
#   'dead.',
#   'getting',
#   'worse.',
#   'people',
#   'want',
#   'law',
#   'order!'],
#  ['crooked',
#   'hillary',
#   'clinton',
#   'made',
#   'facts',
#   'me,',
#   'forgot',
#   'mention',
#   'many',
#   'problems',
#   'country,',
#   'average',
#   'scream!'],
#  ['one',
#   'worse',
#   'judgement',
#   'hillary',
#   'clinton',
#   'corruption',
#   'devastation',
#   'follows',
#   'wherever',
#   'goes.'],
#  ['hillarys',
#   'wars',
#   'middle',
#   'east',
#   'unleashed',
#   'destruction,',
#   'terrorism',
#   'isis',
#   'across',
#   'world.'],
#  ['hillarys',
#   'vision',
#   'borderless',
#   'world',
#   'working',
#   'people',
#   'power,',
#   'jobs,',
#   'safety.'],
#  ['hillary', 'never', 'reform', 'wall', 'street.', 'owned', 'wall', 'street!'],
#  ['way',
#   'life',
#   'threat',
#   'radical',
#   'islam',
#   'hillary',
#   'clinton',
#   'cannot',
#   'even',
#   'bring',
#   'say',
#   'words.'],
#  ['hillarys',
#   'refusal',
#   'mention',
#   'radical',
#   'islam,',
#   'pushes',
#   '550',
#   'increase',
#   'refugees,',
#   'proof',
#   'unfit',
#   'lead',
#   'country.'],
#  ['median',
#   'household',
#   'income',
#   'middle',
#   'class',
#   'since',
#   'obama',
#   'took',
#   'office.',
#   'go',
#   'clinton.'],
#  ['vote',
#   'clintonkaine',
#   'vote',
#   'tpp,',
#   'nafta,',
#   'high',
#   'taxes,',
#   'radical',
#   'regulation,',
#   'massive',
#   'influx',
#   'refugees.'],
#  ['president',
#   'obama',
#   'spoke',
#   'last',
#   'night',
#   'world',
#   'doesnt',
#   'exist.',
#   '70',
#   'people',
#   'think',
# ...
#   'many',
#   'millions',
#   'votes',
#   'anyone',
#   'else,',
#   'me,',
#   'still',
#   'must',
#   'fight'],
#  ['@lilrachiepoo',
#   'thank',
#   'you,',
#   'mr.',
#   'trump,',
#   'personal',
#   'financial',
#   'sacrifices',
#   'journey',
#   '#makeamericagreatagain'],
#  ['@redneckgp',
#   'haters',
#   'there,',
#   'stop',
#   'trashing',
#   'candidate',
#   'put',
#   'america',
#   'first',
#   '#trump'],
#  ['@kirstiealley',
#   'hello',
#   'boys!',
#   'formal',
#   'endorsement',
#   'im',
#   'woman!',
#   'last',
#   'checked',
#   'rudy,',
#   'u',
#   'r',
#   'amazing!'],
#  ['@cam',
#   'reports',
#   'rnc',
#   'received',
#   '1',
#   'million',
#   'postcards',
#   'far!',
#   'get',
#   'info',
#   '##',
#   'ill',
#   'post',
#   '@anncoulter',
#   'http//twitter.com/campaigntrump/status/718572490981646336/photo/1'],
#  ['nobody',
#   'beats',
#   'national',
#   'security.',
#   'http//www.newsmax.com/newsfront/newsmaxfabriziopooldonaldtrump/2016/03/23/id/720556/'],
#  ['looks',
#   'like',
#   'right',
#   'nato.',
#   'doubt.http//foreignpolicy.com/2016/04/06/senatorsslamnatofreeridersincloseddoormeetingwithsecretarygeneral/'],
#  ['@ruokuk',
#   '@glozee1',
#   '@paulmanafort',
#   '@cnn',
#   '@danscavino',
#   'vote',
#   'save',
#   'west.',
#   'dont',
#   'become',
#   'like',
#   'europe',
#   '#wakeupamerica'],
#  ['great',
#   'new',
#   'york.',
#   'catching',
#   'many',
#   'things',
#   'remember,',
#   'still',
#   'running',
#   'major',
#   'business',
#   'campaign',
#   'loving',
#   'it!'],
#  ['@dicristo13',
#   'lets',
#   'policy',
#   'speeches',
#   'immigration,',
#   'economy,',
#   'foreign',
#   'policy,',
#   'nato!'],
#  ['@genie115', '#makeamericagreatagain', 'rt'],
#  ['ted',
#   'cruz',
#   'attacked',
#   'new',
#   'yorkers',
#   'new',
#   'york',
#   'values',
#   'dont',
#   'forget!',
#   'https//www.instagram.com/p/bd6skimghqt/'],
#  ['unbelievable',
#   'evening.',
#   'made',
#   'speech',
#   'front',
#   '17,000',
#   'amazing',
#   'new',
#   'yorkers',
#   'bethpage,',
#   'long',
#   'island',
#   'great',
#   'home!'],
#  ['great',
#   'back',
#   'home!',
#   'looking',
#   'forward',
#   'great',
#   'rally',
#   'tonight',
#   'bethpage,',
#   'long',
#   'island!'],
#  ['good',
#   'morning',
#   'wisconsin!',
#   'polls',
#   'open!',
#   '#votetrump',
#   'today',
#   'makeamericagreatagain!http//bit.ly/1vt2jbscavwi'],
#  ['@foxnews',
#   '@scottbaio',
#   '#donaldtrump',
#   'guy,',
#   'think,',
#   'nerve',
#   'attack',
#   'fight.https//amp.twimg.com/v/4287e37db2b24e089b04cbad8d0c6617'],
#  ['leaving',
#   'superior,',
#   'wisconsin',
#   'now.',
#   'thank',
#   'you!',
#   '#trump2016',
#   '#wiprimaryhttps//www.facebook.com/donaldtrump/posts/101568875100557250'],
#  ['wow,',
#   'great',
#   'news',
#   'wisconsin.',
#   'made',
#   'two',
#   'speeches',
#   'big',
#   'one',
#   'coming',
#   'tonight.',
#   'thank',
#   'you!https//twitter.com/howardkurtz/status/717058440942628864'],
#  ['interviewed',
#   '@seanhannity',
#   '@foxnews',
#   '#wisconsin',
#   'tonight.',
#   'wife,',
#   'melania,',
#   'join',
#   'entire',
#   'show.'],
#  ['great',
#   'day',
#   'wisconsin,',
#   'many',
#   'stops,',
#   'many',
#   'great',
#   'people!',
#   'melania',
#   'joining',
#   'monday.',
#   'big',
#   'crowds.',
#   'make',
#   'america',
#   'great',
#   'again!'],
#  ['great',
#   'night',
#   'west',
#   'allis,',
#   'wisconsin!',
#   'thank',
#   'you!',
#   '#votetrumpwi',
#   '#wiprimary',
#   'https//www.facebook.com/donaldtrump/posts/101568838528007250'],
#  ['thank',
#   'miss',
#   'katies',
#   'diner!#makeamericagreatagain',
#   '#trump2016https//www.facebook.com/donaldtrump/posts/101568819627207250'],
#  ['thank',
#   'new',
#   'york,',
#   'pennsylvania!',
#   '#makeamericagreatagain',
#   '#trump2016'],
#  ['@gopjenna',
#   'dont',
#   'care',
#   'game,',
#   'care',
#   'people.',
#   'thats',
#   'exactly',
#   'people',
#   'love',
#   'much!',
#   '#trump2016'],
#  ['thank', 'you!', '#trump2016', '#wiprimary'],
#  ['@margee11',
#   '#wisconsin',
#   'vote',
#   'smart',
#   '@tedcruz',
#   'records',
#   'r',
#   'sealed..',
#   'hiding?',
#   'save',
#   'america',
#   'w/'],
#  ['thank',
#   'eau',
#   'claire,',
#   'wisconsin.',
#   '#votetrump',
#   'tuesday,',
#   'april',
#   '5th!make',
#   'america',
#   'great',
#   'again!'],
#  ['.@foxnews',
#   'ashamed',
#   'allowing',
#   'experts',
#   'explain',
#   'make',
#   'nuclear',
#   'attack!'],
#  ['wisconsin',
#   'suffered',
#   'great',
#   'loss',
#   'jobs',
#   'trade,',
#   'win,',
#   'bad',
#   'things',
#   'happening',
#   'u.s.',
#   'rapidly',
#   'reversed!'],
#  ['wisconsin',
#   'election.',
#   'jobs,',
#   'trade',
#   'immigration',
#   'big',
#   'factors.',
#   'bring',
#   'jobs',
#   'back',
#   'home',
#   'make',
#   'great',
#   'deals!'],
#  ['@megynkelly',
#   'stopped',
#   'covering',
#   'show,',
#   'ratings',
#   'would',
#   'drop',
#   'like',
#   'rock!',
#   'h',
#   'h',
#   'interview',
#   '@ac360',
#   'beat',
#   'millions!'],
#  ['possible',
#   '@megynkelly',
#   'cover',
#   'anyone',
#   'terrible',
#   'show.',
#   'totally',
#   'misrepresents',
#   'words',
#   'positions!',
#   'bad.'],
#  ['believe',
#   'ted',
#   'cruz,',
#   'killing',
#   'country',
#   'trade',
#   'long,',
#   'put',
#   'wisconsin',
#   'ad',
#   'talking',
#   'trade?'],
#  ['must',
#   'build',
#   'great',
#   'wall',
#   'mexico',
#   'united',
#   'states!http//www.dailymail.co.uk/news/article3518397/momenttwodrugssmugglersfilmednewscrewsneakingusscalingarizonaborderfence.html'],
#  ['1st',
#   'time',
#   'american',
#   'history,',
#   'americas',
#   '16,500',
#   'border',
#   'patrol',
#   'agents',
#   'issue',
#   'presidential',
#   'primary',
#   'endorsementme!',
#   'thank',
#   'you.'],
#  ['national',
#   'border',
#   'patrol',
#   'council',
#   'nbpc',
#   'said',
#   'open',
#   'border',
#   'biggest',
#   'physical',
#   'economic',
#   'threat',
#   'facing',
#   'american',
#   'people!'],
#  ['club',
#   'growth',
#   'said',
#   'ad',
#   '465',
#   'delegates',
#   'cruz',
#   'plus',
#   '143',
#   'delegates',
#   'kasich',
#   '739',
#   'delegates.',
#   'try',
#   'again!'],
#  ['club',
#   'growth,which',
#   'asked',
#   '1,000,000',
#   'extortion',
#   'attempt,',
#   'put',
#   'wisconsin',
#   'ad',
#   'incorrect',
#   'math.what',
#   'dumb',
#   'group!'],
#  ['thank',
#   'you,',
#   'america!',
#   '#trump2016#makeamericagreatagain',
#   'http//bit.ly/1rq7r0hgopnationalpoll'],
#  ['thank',
#   'you,',
#   'wisconsin!',
#   '#votetrump',
#   'next',
#   'tuesday,',
#   'april',
#   '5th!',
#   '#wiprimaryhttp//bit.ly/1rswyojvotetrumpwi'],
#  ['nice',
#   'meeting',
#   '@reince',
#   'priebus',
#   '@gop.',
#   'looking',
#   'forward',
#   'bringing',
#   'party',
#   'together',
#   'happen!'],
#  ['doctrine',
#   'peace',
#   'strength.',
#   '#trump2016',
#   'https//www.facebook.com/donaldtrump/posts/10156866194350725'],
#  ['@susanbirchfiel1',
#   'nothing',
#   'say',
#   'change',
#   'mind!',
#   'woman',
#   'https//twitter.com/carolde/status/715345677409259520'],
#  ['@gearssuxs',
#   '@loudobbsnews',
#   'im',
#   'democrat',
#   'switch',
#   'republican',
#   'vote',
#   'primary.',
#   'great!'],
#  ['thank',
#   'appleton,',
#   'wisconsin!#wiprimary',
#   '#trump2016',
#   'https//www.facebook.com/donaldtrump/posts/101568626756207250'],
#  ['congratulations',
#   '@cnn',
#   'wisdom',
#   'pick',
#   'trump!',
#   '#makeamericagreatagain',
#   '#trump2016'],
#  ['please',
#   'keep',
#   'thoughts',
#   'prayers',
#   'melissa',
#   'young',
#   'miss',
#   'wisconsin',
#   '2005.http//www.cnn.com/2016/03/30/politics/trumpmisswisconsinemotionalmoment/index.html?srtwcnn033016trumpmisswisconsinemotionalmoment0214pmstorylinklinkid22869280'],
#  ['thank',
#   'you,',
#   'new',
#   'york!#makeamericagreatagain',
#   '#trump2016https//www.facebook.com/donaldtrump/posts/101568614056907250'],
#  ['.@davidgregory',
#   'got',
#   'thrown',
#   'tv',
#   'nbc,',
#   'fired',
#   'like',
#   'dog!',
#   '@cnn',
#   'nasty',
#   'me.',
#   'nice!'],
#  ['final',
#   '#s',
#   'announced',
#   'great',
#   'state',
#   'mo.',
#   'wins!',
#   'new',
#   'certified',
#   '#s',
#   'show',
#   '365',
#   'vote',
#   'increase',
#   '@',
#   'least',
#   '12',
#   'delegates!'],
#  ['reporter', 'touching', 'leave', 'news', 'conference?', 'hand??'],
#  ['victory',
#   'press',
#   'conference',
#   'over.',
#   'allowed',
#   'grab',
#   'shout',
#   'questions?',
#   'press',
#   'charges?'],
#  ['wow,',
#   'corey',
#   'lewandowski,',
#   'campaign',
#   'manager',
#   'decent',
#   'man,',
#   'charged',
#   'assaulting',
#   'reporter.',
#   'look',
#   'tapesnothing',
#   'there!'],
#  ['millions',
#   'votes/hundreds',
#   'dels',
#   'cruz',
#   'kasich,',
#   'yet',
#   'treated',
#   'properly',
#   'republican',
#   'party',
#   'rnc.'],
#  ['wow,',
#   '@cnn',
#   'nothing',
#   'opponents',
#   'shows.',
#   'really',
#   'onesided',
#   'unfair',
#   'reporting.',
#   'maybe',
#   'shouldnt',
#   'townhall',
#   'tonight!'],
#  ['need',
#   'secure',
#   'borders',
#   'asap.',
#   'games,',
#   'must',
#   'smart,',
#   'tough',
#   'vigilant.',
#   'make',
#   'america',
#   'great',
#   'make',
#   'america',
#   'strong',
#   'again!'],
#  ['lyin',
#   'ted,',
#   'already',
#   'beaten',
#   'debates,',
#   'way',
#   'ahead',
#   'votes',
#   'delegates.',
#   'focus',
#   'jobs',
#   'illegal',
#   'imm!'],
#  ['detainee',
#   'released',
#   'gitmo',
#   'killed',
#   'american.',
#   'socalled',
#   'leaders',
#   'ever',
#   'learn!'],
#  ['united',
#   'states',
#   'cannot',
#   'continue',
#   'make',
#   'bad,',
#   'onesided',
#   'trade',
#   'deals.',
#   'many',
#   'jobs',
#   'give',
#   'up.',
#   'more!'],
#  ['see',
#   'lyin',
#   'ted,',
#   'even',
#   '@dailybeast',
#   'fan',
#   'mine',
#   'says',
#   'story',
#   'came',
#   'rubio,',
#   'trump!'],
#  ['show',
#   'unfair',
#   'republican',
#   'primary',
#   'politics',
#   'be,',
#   'state',
#   'louisiana',
#   'get',
#   'less',
#   'delegates',
#   'cruzlawsuit',
#   'coming'],
#  ['another',
#   'radical',
#   'islamic',
#   'attack,',
#   'time',
#   'pakistan,',
#   'targeting',
#   'christian',
#   'women',
#   'children.',
#   'least',
#   '67',
#   'dead,400',
#   'injured.',
#   'alone',
#   'solve'],
#  ['happy', 'easter', 'all,', 'great', 'day!'],
#  ['statement',
#   'nato',
#   'obsolete',
#   'disproportionately',
#   'expensive',
#   'unfair',
#   'u.s.',
#   'now,',
#   'finally,',
#   'receiving',
#   'plaudits!'],
#  ['remember,',
#   'candidate',
#   'selffunding.',
#   'given',
#   'little',
#   'credit',
#   'voters,',
#   'bought',
#   'like',
#   'others!'],
#  ['dont',
#   'believe',
#   '@foxnews',
#   'polls,',
#   'another',
#   'phony',
#   'hit',
#   'job',
#   'me.',
#   'beat',
#   'hillary',
#   'clinton',
#   'easily',
#   'general',
#   'election.'],
#  ['wisconsins',
#   'economy',
#   'poorly',
#   'like',
#   'everywhere',
#   'else',
#   'u.s.,',
#   'jobs',
#   'leaving.',
#   'make',
#   'economy',
#   'strong',
#   'bring',
#   'jobs'],
#  ['nobody',
#   'protect',
#   'nation',
#   'like',
#   'j.',
#   'trump.',
#   'military',
#   'greatly',
#   'strengthened',
#   'borders',
#   'strong.',
#   'illegals',
#   'out!'],
#  ['lyin',
#   'ted',
#   'cruz',
#   'trying',
#   'convince',
#   'prople',
#   'problems',
#   'national',
#   'enq.were',
#   'caused',
#   'me.',
#   'nothing',
#   'story!'],
#  ['press',
#   'going',
#   'way',
#   'convince',
#   'people',
#   'like',
#   'respect',
#   'women,',
#   'know',
#   'opposite!'],
#  ['media',
#   'women',
#   'wow,',
#   'tough',
#   'business.',
#   'nobody',
#   'respect',
#   'women',
#   'trump!'],
#  ['@tytan01',
#   'dear',
#   '@cnn,',
#   'quick',
#   'google',
#   'twitter',
#   'search',
#   '15,000',
#   'womens',
#   'groups',
#   'supporting',
#   'donaldtrump.',
#   'stop',
#   'lying.'],
#  ['top',
#   'suspect',
#   'paris',
#   'massacre,',
#   'salah',
#   'abdeslam,',
#   'also',
#   'knew',
#   'brussels',
#   'attack,',
#   'longer',
#   'talking.',
#   'weak',
#   'leaders,',
#   'ridiculous',
#   'laws!'],
#  ['wow,',
#   'released',
#   '67',
#   'million',
#   'negative',
#   'ads',
#   'spent',
#   'me.',
#   'still',
#   'number',
#   'one',
#   'lot?'],
#  ['didnt',
#   'start',
#   'fight',
#   'lyinted',
#   'cruz',
#   'gq',
#   'cover',
#   'pic',
#   'melania,',
#   'did.',
#   'knew',
#   'pac',
#   'putting',
#   'hence,',
#   'lyin',
#   'ted!'],
#  ['big',
#   'federal',
#   'lawsuit',
#   'similar',
#   'certain',
#   'ways',
#   'u',
#   'case',
#   'press',
#   'refuses',
#   'write',
#   'it.',
#   'lostmonster',
#   'story!'],
#  ['europe',
#   'u.s.',
#   'must',
#   'immediately',
#   'stop',
#   'taking',
#   'people',
#   'syria.',
#   'destruction',
#   'civilization',
#   'know',
#   'it!',
#   'sad!'],
#  ['announced',
#   'many',
#   '5000',
#   'isis',
#   'fighters',
#   'infiltrated',
#   'europe.',
#   'also,',
#   'many',
#   'u.s.',
#   'told',
#   'so!',
#   'alone',
#   'fix',
#   'problem!'],
#  ['amazing',
#   'often',
#   'right,',
#   'criticized',
#   'media.',
#   'illegal',
#   'immigration,',
#   'take',
#   'oil,',
#   'build',
#   'wall,',
#   'muslims,',
#   'nato!'],
#  ['remember',
#   'recently',
#   'said',
#   'brussels',
#   'hell',
#   'hole',
#   'mess',
#   'failing',
#   '@nytimes',
#   'wrote',
#   'critical',
#   'article.',
#   'right!'],
#  ['@donvito08',
#   'picture',
#   'worth',
#   'thousand',
#   'words',
#   '#lyingted',
#   '#nevercruz',
#   '@melaniatrump'],
#  ['make', 'america', 'great', 'again!'],
#  ['think',
#   'jebs',
#   'endorsement',
#   'hurts',
#   'lyin',
#   'ted.',
#   'jeb',
#   'spent',
#   '150,000,000',
#   'got',
#   'nothing.',
#   'spent',
#   'fraction',
#   'first!'],
#  ['best',
#   'far',
#   'fighting',
#   'terror.',
#   'im',
#   'one',
#   'right',
#   'beginning,',
#   'lyin',
#   'ted',
#   'others',
#   'copying',
#   'me.'],
#  ['watched',
#   'hillary',
#   'deliver',
#   'prepackaged',
#   'speech',
#   'terror.',
#   'shes',
#   'office',
#   'fighting',
#   'terror',
#   '20',
#   'years',
#   'look',
#   'are!'],
#  ['low',
#   'energy',
#   'jeb',
#   'bush',
#   'endorsed',
#   'man',
#   'truly',
#   'hates,',
#   'lyin',
#   'ted',
#   'cruz.',
#   'honestly,',
#   'cant',
#   'blame',
#   'jeb',
#   'drove',
#   'oblivion!'],
#  ['lyin',
#   'ted',
#   'cruz',
#   'steals',
#   'foreign',
#   'policy',
#   'me,',
#   'lines',
#   'michael',
#   'douglas',
#   'another',
#   'dishonest',
#   'politician.'],
#  ['lyin',
#   'ted',
#   'cruz',
#   'denied',
#   'anything',
#   'g.q.',
#   'model',
#   'photo',
#   'post',
#   'melania.',
#   'thats',
#   'call',
#   'lyin',
#   'ted!'],
#  ['hopefully',
#   'republican',
#   'party',
#   'come',
#   'together',
#   'big',
#   'win',
#   'november,',
#   'paving',
#   'way',
#   'many',
#   'great',
#   'supreme',
#   'court',
#   'justices!'],
#  ['much',
#   'bigger',
#   'win',
#   'anticipated',
#   'arizona.',
#   'thank',
#   'you,',
#   'never',
#   'forget!'],
#  ['incompetent',
#   'hillary,',
#   'despite',
#   'horrible',
#   'attack',
#   'brussels',
#   'today,',
#   'wants',
#   'borders',
#   'weak',
#   'openand',
#   'let',
#   'muslims',
#   'flow',
#   'in.',
#   'way!'],
#  ['lyin',
#   'ted',
#   'cruz',
#   'used',
#   'picture',
#   'melania',
#   'g.q.',
#   'shoot',
#   'ad.',
#   'careful,',
#   'lyin',
#   'ted,',
#   'spill',
#   'beans',
#   'wife!'],
#  ['pres.',
#   'obama',
#   'leave',
#   'baseball',
#   'game',
#   'cuba',
#   'immediately',
#   'get',
#   'home',
#   'washington',
#   '#potus,',
#   'serious',
#   'emergency',
#   'belongs!'],
#  ['obama,',
#   'others,',
#   'weak,',
#   'politically',
#   'correct,',
#   'terror',
#   'groups',
#   'forming',
#   'getting',
#   'stronger!',
#   'shame.'],
#  ['heart',
#   'prayers',
#   'go',
#   'victims',
#   'terrible',
#   '#brussels',
#   'tragedy.',
#   'madness',
#   'must',
#   'stopped,',
#   'stop',
#   'it.'],
#  ['watch',
#   'clip',
#   'earlier',
#   'year.',
#   'time',
#   'time',
#   'right',
#   'terrorism.',
#   'time',
#   'get',
#   'tough!',
#   'https//www.instagram.com/p/bdqvbinghwm/'],
#  ['proven',
#   'far',
#   'correct',
#   'terrorism',
#   'anybody',
#   'even',
#   'close.',
#   'hopefully',
#   'az',
#   'ut',
#   'voting',
#   'today!'],
#  ['make', 'america', 'great', 'again!'],
#  ['president',
#   'obama',
#   'looks',
#   'sounds',
#   'ridiculous',
#   'making',
#   'speech',
#   'cuba,',
#   'especially',
#   'shadows',
#   'brussels.',
#   'treated',
#   'badly!'],
#  ['remember',
#   'beautiful',
#   'safe',
#   'place',
#   'brussels',
#   'was.',
#   'anymore,',
#   'different',
#   'world!',
#   'u.s.',
#   'must',
#   'vigilant',
#   'smart!'],
#  ['@barrong510', 'media', 'corrupt!', 'people', 'fighting', 'you.'],
#  ['wow,',
#   'president',
#   'obama',
#   'landed',
#   'cuba,',
#   'big',
#   'deal,',
#   'raul',
#   'castro',
#   'wasnt',
#   'even',
#   'greet',
#   'him.',
#   'greeted',
#   'pope',
#   'others.',
#   'respect'],
#  ['highly',
#   'overrated',
#   'anchor,',
#   '@megynkelly,',
#   'allowed',
#   'constantly',
#   'say',
#   'bad',
#   'things',
#   'show,',
#   'cant',
#   'fight',
#   'back?',
#   'wrong!'],
#  ['protesters',
#   'blocked',
#   'major',
#   'highway',
#   'yesterday,',
#   'delaying',
#   'entry',
#   'rally',
#   'arizona',
#   'hours,',
#   'media',
#   'blames',
#   'supporters!'],
#  ['horrendous',
#   'protesters,',
#   'scream,',
#   'curse',
#   'punch,',
#   'shut',
#   'roads/doors',
#   'rallies,',
#   'never',
#   'blamed',
#   'media?',
#   'sad!'],
#  ['rallies',
#   'utah',
#   'arizona',
#   'great!',
#   'tremendous',
#   'crowds',
#   'spirit.',
#   'returned',
#   'going',
#   'back',
#   'soon.'],
#  ['@jojo2foxy',
#   'afraid',
#   'anything',
#   'anyone',
#   'thats',
#   'president',
#   'usa',
#   'needs',
#   'unite',
#   'us',
#   'knock',
#   'socks',
#   'enemies!'],
#  ...]

# %% [markdown]
# ### Preparing Document-Term Matrix

# %%
# Creating the term dictionary of our courpus, where every unique term is assigned an index. 
dictionary = corpora.Dictionary(doc_clean)

# Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]

# %% [markdown]
# ### Running LDA Model

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# %%
# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=5, id2word = dictionary, passes=5)

# %%
print(ldamodel.print_topics(num_topics=3, num_words=3))
# Out:
# [(1, '0.004*"people" + 0.004*"last" + 0.004*"like"'), (0, '0.010*"new" + 0.009*"would" + 0.008*"like"'), (3, '0.006*"great" + 0.005*"think" + 0.004*"new"')]
