# %% [markdown]
# # Topic Modelling

# %% [markdown]
# In this project, I will try to compare the tweets of Donald Trump, Barrack Obama, and Hillary Clinton to come up with meaningful insights

# %% [markdown]
# In this notebook, I will try to classify their tweets under different topics to judge who talks about what

# %% [markdown]
# There are 3 CSV files which will be used:
# 1. DonaldTrumpClean
# 2. BarackObamaClean
# 3. HillaryClintonClean
#
# All 3 have the same structure
# date,retweet,text,author

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string

import gensim
from gensim import corpora

# %% [markdown]
# Read the clean data

# %%
trump = pd.read_csv("data/DonaldTrumpClean.csv")
obama = pd.read_csv("data/BarackObamaClean.csv")
clinton = pd.read_csv("data/HillaryClintonClean.csv")

# %%
print(len(trump), len(obama), len(clinton))
# Out:
# 8439 2125 3256

# %% [markdown]
# ## Topic Modelling

# %%
trumpTweetList = list(trump.text)

# %% [markdown]
# ### Cleaning and Preprocessing

# %% [markdown]
# Cleaning is an important step before any text mining task, in this step, we will remove the punctuations, stopwords and normalize the corpus.

# %%
stop_words = set(stopwords.words('english'))
stop_words.update(['realdonaldtrump', '@realdonaldtrump', 'trump', 'donald', 'Donald trump'])
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()

def clean(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop_words])
#     punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
#     normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

doc_clean = [clean(doc).split() for doc in trumpTweetList]

# %%
stop_words
# Out:
# {'@realdonaldtrump',
#  'Donald trump',
#  'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'donald',
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  'realdonaldtrump',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'trump',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
doc_clean
# Out:
# [['statement'],
#  ['really', 'america', 'terrible'],
#  ['medium',
#   'establishment',
#   'want',
#   'race',
#   'badly',
#   'never',
#   'drop',
#   'race',
#   'never',
#   'let',
#   'supporter',
#   'down',
#   'maga'],
#  ['wow',
#   'cnn',
#   'town',
#   'hall',
#   'question',
#   'given',
#   'crooked',
#   'hillary',
#   'clinton',
#   'advance',
#   'big',
#   'debate',
#   'bernie',
#   'sander',
#   'hillary',
#   'cnn',
#   'fraud'],
#  ['debate', 'poll', 'look', 'great', 'thank', 'youmaga', 'americafirst'],
#  ['saying',
#   'clinton',
#   'campaign',
#   'anticatholic',
#   'bigotry',
#   'httpbitly2dcbtvkcrooked'],
#  ['thank',
#   'u',
#   'navy',
#   'protecting',
#   'country',
#   'time',
#   'peace',
#   'war',
#   'together',
#   'make',
#   'america',
#   'safe',
#   'great',
#   'again'],
#  ['little',
#   'pickup',
#   'dishonest',
#   'medium',
#   'incredible',
#   'information',
#   'provided',
#   'wikileaks',
#   'dishonest',
#   'rigged',
#   'system'],
#  ['thank',
#   'florida',
#   'movement',
#   'never',
#   'seen',
#   'never',
#   'seen',
#   'again',
#   'let',
#   'get',
#   'votetrumppence16',
#   '118',
#   'maga'],
#  ['foul',
#   'mouthed',
#   'sen',
#   'john',
#   'mccain',
#   'begged',
#   'support',
#   'primary',
#   'gave',
#   'won',
#   'dropped',
#   'locker',
#   'room',
#   'remark'],
#  ['disloyal',
#   'r',
#   'far',
#   'difficult',
#   'crooked',
#   'hillary',
#   'come',
#   'side',
#   'dont',
#   'know',
#   'win',
#   'teach',
#   'them'],
#  ['exception',
#   'cheating',
#   'bernie',
#   'nom',
#   'dems',
#   'always',
#   'proven',
#   'far',
#   'loyal',
#   'republican'],
#  ['nice', 'shackle', 'taken', 'fight', 'america', 'way', 'want', 'to'],
#  ['weak',
#   'ineffective',
#   'leader',
#   'paul',
#   'ryan',
#   'bad',
#   'conference',
#   'call',
#   'member',
#   'went',
#   'wild',
#   'disloyalty'],
#  ['despite',
#   'winning',
#   'second',
#   'debate',
#   'landslide',
#   'every',
#   'poll',
#   'hard',
#   'well',
#   'paul',
#   'ryan',
#   'others',
#   'give',
#   'zero',
#   'support'],
#  ['wow',
#   'cnn',
#   'got',
#   'caught',
#   'fixing',
#   'focus',
#   'group',
#   'order',
#   'make',
#   'crooked',
#   'hillary',
#   'look',
#   'better',
#   'really',
#   'pathetic',
#   'totally',
#   'dishonest'],
#  ['hillaryclinton', 'lawdebates2016'],
#  ['team',
#   'deplorables',
#   'taking',
#   'twitter',
#   'account',
#   'tonight',
#   'debatemakeamericagreatagain'],
#  ['many',
#   'selfrighteous',
#   'hypocrite',
#   'watch',
#   'poll',
#   'number',
#   'election',
#   'go',
#   'down'],
#  ['maidaa17',
#   'gop',
#   'traitor',
#   'supporting',
#   'u',
#   'voting',
#   'her',
#   'destroying',
#   'america'],
#  ['wow',
#   'hear',
#   'bill',
#   'clinton',
#   'statement',
#   'bad',
#   'obamacare',
#   'is',
#   'hillary',
#   'happy',
#   'saying',
#   'repeal',
#   'replace'],
#  ['watching',
#   'great',
#   'governor',
#   'mikepence',
#   'live',
#   'tweeting',
#   'vp',
#   'debate',
#   'tonight',
#   'starting',
#   '830pm',
#   'est',
#   'enjoy'],
#  ['announced',
#   'iraq',
#   'u',
#   'preparing',
#   'battle',
#   'reclaim',
#   'mosul',
#   'announce',
#   'this',
#   'make',
#   'mission',
#   'much',
#   'harder'],
#  ['melania',
#   'extend',
#   'warmest',
#   'greeting',
#   'observing',
#   'rosh',
#   'hashanah',
#   'united',
#   'state',
#   'israel',
#   'around',
#   'world'],
#  ['bernie',
#   'pull',
#   'endorsement',
#   'crooked',
#   'hillary',
#   'decieved',
#   'attacked',
#   'supporter'],
#  ['trumplican2016',
#   'realdonaldtrump',
#   'massive',
#   'turnout',
#   'you',
#   'mr',
#   'poll',
#   'dont',
#   'register',
#   'pulse',
#   'people'],
#  ['created',
#   'ten',
#   'thousand',
#   'job',
#   'bring',
#   'back',
#   'great',
#   'american',
#   'prosperity',
#   'hillary',
#   'created',
#   'job',
#   'fbi',
#   'doj'],
#  ['know',
#   'complex',
#   'tax',
#   'law',
#   'better',
#   'anyone',
#   'ever',
#   'run',
#   'president',
#   'one',
#   'fix',
#   'them',
#   'failingnytimes'],
#  ['wow',
#   'saw',
#   'really',
#   'bad',
#   'cnn',
#   'rating',
#   'people',
#   'dont',
#   'want',
#   'watch',
#   'bad',
#   'product',
#   'build',
#   'crooked',
#   'hillary'],
#  ['socalled',
#   'commission',
#   'presidential',
#   'debate',
#   'admitted',
#   'u',
#   'djt',
#   'audio',
#   'sound',
#   'level',
#   'bad',
#   'didnt',
#   'fix',
#   'it'],
#  ['crooked',
#   'h',
#   'nasty',
#   'sander',
#   'supporter',
#   'behind',
#   'closed',
#   'door',
#   'owned',
#   'wall',
#   'st',
#   'politician',
#   'hrc',
#   'youhttpwwwpoliticocomstory201609hillaryclintonberniesanderssupportersaudioleak228997'],
#  ['believe',
#   'americafirst',
#   'mean',
#   'family',
#   'first',
#   'childcare',
#   'plan',
#   'reflects',
#   'need',
#   'modern',
#   'workingclass',
#   'family',
#   'imwithyou'],
#  ['people',
#   'knocking',
#   'tweeting',
#   'three',
#   'oclock',
#   'morning',
#   'least',
#   'know',
#   'there',
#   'awake',
#   'answer',
#   'call'],
#  ['isnt',
#   'hillary',
#   '50',
#   'point',
#   'ahead',
#   'maybe',
#   'email',
#   'scandal',
#   'policy',
#   'spread',
#   'isi',
#   'calling',
#   'million',
#   'american',
#   'deplorables'],
#  ['people',
#   'really',
#   'smart',
#   'cancelling',
#   'subscription',
#   'dallas',
#   'arizona',
#   'paper',
#   'usa',
#   'today',
#   'lose',
#   'reader',
#   'people',
#   'get',
#   'it'],
#  ['remember',
#   'dont',
#   'believe',
#   'source',
#   'said',
#   'dishonest',
#   'medium',
#   'dont',
#   'name',
#   'source',
#   'source',
#   'dont',
#   'exist'],
#  ['wow',
#   'crooked',
#   'hillary',
#   'duped',
#   'used',
#   'worst',
#   'miss',
#   'u',
#   'hillary',
#   'floated',
#   'angel',
#   'without',
#   'checking',
#   'past',
#   'terrible'],
#  ['anytime',
#   'see',
#   'story',
#   'campaign',
#   'saying',
#   'source',
#   'said',
#   'believe',
#   'it',
#   'source',
#   'made',
#   'lie'],
#  ['wow',
#   'see',
#   'badly',
#   'cnn',
#   'clinton',
#   'news',
#   'network',
#   'rating',
#   'people',
#   'like',
#   'donlemon',
#   'could',
#   'expect',
#   'more'],
#  ['hillary',
#   'profit',
#   'rigged',
#   'system',
#   'fighting',
#   'you',
#   'remember',
#   'simple',
#   'phrase',
#   'followthemoney',
#   'httpswwwfacebookcomdonaldtrumpvideos10157784190830725'],
#  ['condolence',
#   'involved',
#   'today',
#   'horrible',
#   'accident',
#   'nj',
#   'deepest',
#   'gratitude',
#   'amazing',
#   'first',
#   'responder'],
#  ['every',
#   'online',
#   'poll',
#   'time',
#   'magazine',
#   'drudge',
#   'etc',
#   'winning',
#   'debate',
#   'thank',
#   'fox',
#   'friend',
#   'reporting'],
#  ['supporter',
#   'best',
#   '18',
#   'million',
#   'hardworking',
#   'people',
#   'know',
#   'again',
#   'shatter',
#   'recordhttpbitlyshatterrecords'],
#  ['unbelievable',
#   'evening',
#   'melbourne',
#   'florida',
#   'w',
#   '15000',
#   'supporter',
#   'additional',
#   '12000',
#   'could',
#   'get',
#   'in',
#   'thank',
#   'you',
#   'trumptrain',
#   'maga'],
#  ['great',
#   'afternoon',
#   'little',
#   'havana',
#   'hispanic',
#   'community',
#   'leader',
#   'thank',
#   'support',
#   'imwithyou'],
#  ['last',
#   '24',
#   'hr',
#   'raised',
#   '13m',
#   'online',
#   'donation',
#   'national',
#   'call',
#   'day',
#   'still',
#   'going',
#   'thank',
#   'america',
#   'maga'],
#  ['well',
#   'theyre',
#   'saying',
#   'nbc',
#   'presidential',
#   'forum',
#   'last',
#   'night',
#   'big',
#   'debate',
#   'nice'],
#  ['thank',
#   'you',
#   'trumpwon',
#   'magahttpwwwdailymailcouknewsarticle3809204mostsnappollstrumpwinningdebatelandslidehtml'],
#  ['hillary',
#   'failing',
#   '30',
#   'year',
#   'getting',
#   'job',
#   'done',
#   'never',
#   'change'],
#  ['1', 'trend', 'twitter', 'right', 'trumpwon', 'thank', 'you'],
#  ['every',
#   'poll',
#   'last',
#   'night',
#   'presidential',
#   'debate',
#   'except',
#   'little',
#   'watched',
#   'cnn',
#   'poll'],
#  ['bar',
#   'full',
#   'undecideds',
#   'democratshttpnypostcom20160926thebestdebatetakescomefrominsidethebar'],
#  ['really',
#   'enjoyed',
#   'debate',
#   'last',
#   'nightcrooked',
#   'hillary',
#   'say',
#   'going',
#   'many',
#   'thingswhy',
#   'hasnt',
#   'done',
#   'last',
#   '30',
#   'year'],
#  ['thank',
#   'you',
#   'four',
#   'new',
#   'debatenight',
#   'poll',
#   'movement',
#   'winning',
#   'together',
#   'make',
#   'america',
#   'safe',
#   'great',
#   'againhttpwwwdonaldjtrumpcom'],
#  ['drudgereports',
#   'first',
#   'presidential',
#   'debate',
#   'polltrump',
#   '80clinton',
#   '20join',
#   'movement',
#   'today',
#   'let',
#   'maga',
#   'httpwwwdonaldjtrumpcom'],
#  ['newtgingrich', 'said', 'historic', 'victory', 'trump', 'nice'],
#  ['wow',
#   'great',
#   'debate',
#   'poll',
#   'except',
#   'cnn',
#   'dont',
#   'watch',
#   'thank',
#   'you'],
#  ['thank',
#   'governor',
#   'mikepencelets',
#   'make',
#   'america',
#   'safe',
#   'great',
#   'american',
#   'people',
#   'americafirst',
#   'debates2016httpstwittercommikepencestatus780615043809435649'],
#  ['thank', 'senator', 'tedcruzdebates2016', 'maga'],
#  ['russia',
#   'warhead',
#   'ever',
#   'n',
#   'korea',
#   'testing',
#   'nuke',
#   'iran',
#   'got',
#   'sweetheart',
#   'deal',
#   'keep',
#   'theirs',
#   'thanks',
#   'hillaryclinton'],
#  ['hillary',
#   'clinton',
#   'failed',
#   'world',
#   'libyasyriairaniraqasia',
#   'pivotrussian',
#   'resetbenghazidebatenight'],
#  ['stand', 'police', 'protect', 'american', 'debates2016', 'maga'],
#  ['simple',
#   'fact',
#   'hillaryclinton',
#   'typical',
#   'politician',
#   'talk',
#   'action',
#   'debates2016'],
#  ['hillary', 'bad', 'tax', 'habit'],
#  ['hillaryclinton',
#   'part',
#   'rigged',
#   'dc',
#   'system',
#   '30',
#   'year',
#   'would',
#   'take',
#   'policy',
#   'advice',
#   'her',
#   'debates2016'],
#  ['isnt', 'hillary', 'clinton', '50', 'point', 'aheaddebatenight'],
#  ['team',
#   'deplorables',
#   'managing',
#   'twitter',
#   'account',
#   'evening',
#   'debate',
#   'tune',
#   'indebatenight',
#   'trumppence16'],
#  ['new',
#   'national',
#   'bloomberg',
#   'poll',
#   'released',
#   'thank',
#   'you',
#   'join',
#   'movement',
#   'httpwwwdonaldjtrumpcom',
#   'trumptrain',
#   'maga'],
#  ['really',
#   'sad',
#   'news',
#   'great',
#   'arnold',
#   'palmer',
#   'king',
#   'died',
#   'noone',
#   'like',
#   'true',
#   'champion',
#   'truly',
#   'missed'],
#  ['five',
#   'people',
#   'killed',
#   'washington',
#   'state',
#   'middle',
#   'eastern',
#   'immigrant',
#   'many',
#   'people',
#   'died',
#   'weekend',
#   'ohio',
#   'drug',
#   'overdoses',
#   'nc',
#   'riot'],
#  ['readout',
#   'meeting',
#   'israeli',
#   'prime',
#   'minister',
#   'benjamin',
#   'netanyahuhttpswwwfacebookcomdonaldtrumpposts101577591495907250'],
#  ['looking',
#   'forward',
#   'meeting',
#   'benjamin',
#   'netanyahu',
#   'tower',
#   '1000',
#   'am'],
#  ['bernie',
#   'sander',
#   'gave',
#   'hillary',
#   'dem',
#   'nomination',
#   'gave',
#   'email',
#   'issue',
#   'gotten',
#   'bigger'],
#  ['many',
#   'team',
#   'staff',
#   'bernie',
#   'sander',
#   'treated',
#   'badly',
#   'hillary',
#   'clinton',
#   'campaign',
#   'like',
#   'trade',
#   'lot'],
#  ['dopey',
#   'mark',
#   'cuban',
#   'failed',
#   'benefactor',
#   'fame',
#   'want',
#   'sit',
#   'front',
#   'row',
#   'perhaps',
#   'put',
#   'gennifer',
#   'flower',
#   'right',
#   'alongside',
#   'him'],
#  ['kellyannepolls',
#   'headed',
#   'win',
#   'say',
#   'professor',
#   'predicted',
#   '30',
#   'year',
#   'presidential',
#   'outcome',
#   'httpwposthqg2'],
#  ['sentedcruz',
#   'endorsement',
#   'wonderful',
#   'surprise',
#   'greatly',
#   'appreciate',
#   'support',
#   'tremendous',
#   'victory',
#   'november',
#   '8th'],
#  ['crooked',
#   'hillary',
#   'bad',
#   'judgement',
#   'forced',
#   'announce',
#   'would',
#   'go',
#   'charlotte',
#   'saturday',
#   'grandstand',
#   'dem',
#   'pol',
#   'said',
#   'way',
#   'dumb'],
#  ['spoke',
#   'governor',
#   'patmccrorync',
#   'north',
#   'carolina',
#   'today',
#   'tremendous',
#   'job',
#   'tough',
#   'circumstance'],
#  ['great',
#   'new',
#   'poll',
#   'thank',
#   'nevada',
#   'north',
#   'carolina',
#   'ohio',
#   'join',
#   'movement',
#   'today',
#   'let',
#   'magahttpwwwdonaldjtrumpcom'],
#  ['hopefully',
#   'violence',
#   'unrest',
#   'charlotte',
#   'come',
#   'immediate',
#   'end',
#   'injured',
#   'get',
#   'well',
#   'soon',
#   'need',
#   'unity',
#   'leadership'],
#  ['situation',
#   'tulsa',
#   'charlotte',
#   'tragic',
#   'must',
#   'come',
#   'together',
#   'make',
#   'america',
#   'safe',
#   'again'],
#  ['movement',
#   'campaign',
#   'leaving',
#   'past',
#   'behind',
#   'changing',
#   'future',
#   'together',
#   'make',
#   'america',
#   'safe',
#   'great',
#   'again'],
#  ['thank',
#   'kenansville',
#   'north',
#   'carolina',
#   'remember',
#   'november',
#   '8th',
#   'special',
#   'interest',
#   'gravy',
#   'train',
#   'coming',
#   'abrupt',
#   'end',
#   'maga'],
#  ['thank',
#   'high',
#   'point',
#   'nc',
#   'fight',
#   'every',
#   'neglected',
#   'part',
#   'nation',
#   'fight',
#   'bring',
#   'u',
#   'together',
#   'one',
#   'american',
#   'people'],
#  ['hillary',
#   'clinton',
#   'taking',
#   'day',
#   'again',
#   'need',
#   'rest',
#   'sleep',
#   'well',
#   'hillary',
#   'see',
#   'debate'],
#  ['people',
#   'notice',
#   'hillary',
#   'copying',
#   'airplane',
#   'rally',
#   'put',
#   'plane',
#   'behind',
#   'like',
#   'beginning'],
#  ['crooked',
#   'hillary',
#   'fighting',
#   'isi',
#   'whatever',
#   'doing',
#   'year',
#   'new',
#   'idea',
#   'time',
#   'change'],
#  ['together',
#   'make',
#   'america',
#   'safe',
#   'great',
#   'again',
#   'imwithyou',
#   'americafirst'],
#  ['hillary',
#   'clinton',
#   'weakness',
#   'secretary',
#   'state',
#   'emboldened',
#   'terrorist',
#   'worldcont',
#   'httpbitly2cnwnwe'],
#  ['someone',
#   'told',
#   'ok',
#   'turn',
#   'terrorist',
#   'want',
#   'destroy',
#   'country',
#   'people',
#   'get',
#   'thru',
#   'system'],
#  ['great',
#   'job',
#   'law',
#   'enforcement',
#   'proud',
#   'embrace',
#   'without',
#   'them',
#   'dont',
#   'country'],
#  ['terrible',
#   'attack',
#   'ny',
#   'nj',
#   'mn',
#   'weekend',
#   'thinking',
#   'victim',
#   'family',
#   'american',
#   'need',
#   'strong'],
#  ['leadership',
#   'obama',
#   'clinton',
#   'american',
#   'experienced',
#   'attack',
#   'home',
#   'victory',
#   'abroad',
#   'time',
#   'change',
#   'playbook'],
#  ['happy', 'birthday', 'united', 'state', 'air', 'force'],
#  ['would',
#   'like',
#   'express',
#   'warmest',
#   'regard',
#   'best',
#   'wish',
#   'condolence',
#   'family',
#   'victim',
#   'horrible',
#   'bombing',
#   'nyc'],
#  ['lawyer',
#   'want',
#   'sue',
#   'failing',
#   'nytimes',
#   'badly',
#   'irresponsible',
#   'intent',
#   'said',
#   'now',
#   'watching',
#   'really',
#   'disgusting'],
#  ['failing',
#   'nytimes',
#   'gone',
#   'nut',
#   'crooked',
#   'hillary',
#   'badly',
#   'willing',
#   'say',
#   'anything',
#   'become',
#   'laughingstock',
#   'rag'],
#  ['wacky',
#   'nytimesdowd',
#   'hardly',
#   'know',
#   'me',
#   'make',
#   'thing',
#   'never',
#   'said',
#   'boring',
#   'interview',
#   'column',
#   'neurotic',
#   'dope'],
#  ['cnn',
#   'doesnt',
#   'get',
#   'it',
#   'thats',
#   'rating',
#   'low',
#   'getting',
#   'worse',
#   'boring',
#   'antitrump',
#   'panelist',
#   'mostly',
#   'loser',
#   'life'],
#  ['never',
#   'met',
#   'former',
#   'defense',
#   'secretary',
#   'robert',
#   'gate',
#   'know',
#   'nothing',
#   'me',
#   'look',
#   'result',
#   'guidance',
#   'total',
#   'disaster'],
#  ['crooked',
#   'hillary',
#   'want',
#   'take',
#   '2nd',
#   'amendment',
#   'right',
#   'away',
#   'gun',
#   'taken',
#   'heavily',
#   'armed',
#   'secret',
#   'service',
#   'detail',
#   'maybe',
#   'not'],
#  ['thought',
#   'prayer',
#   'go',
#   'phillypolice',
#   'penn',
#   'police',
#   'officer',
#   'philadelphiahttpabc7newscomnews2policeofficersshotinwestphiladelphiasuspectdead1515355utmsourcedlvritutmmediumtwitter'],
#  ['trump',
#   'birther',
#   'event',
#   'greatest',
#   'trick',
#   'he',
#   'ever',
#   'pulledhttpwapost2cqoaqc'],
#  ['arrived',
#   'texas',
#   'informed',
#   'two',
#   'fortworthpd',
#   'officer',
#   'shot',
#   'thought',
#   'prayer',
#   'them'],
#  ['leaving',
#   'miami',
#   'houston',
#   'oklahoma',
#   'colorado',
#   'miami',
#   'crowd',
#   'fantastic'],
#  ['great',
#   'parade',
#   'village',
#   'love',
#   'all',
#   'maga',
#   'thank',
#   'incredible',
#   'supporti',
#   'forget'],
#  ['truly',
#   'honored',
#   'grateful',
#   'receiving',
#   'much',
#   'support',
#   'american',
#   'heroeshttpbitly2cshfxf'],
#  ['going',
#   'brand',
#   'new',
#   'international',
#   'hotel',
#   'dc',
#   'major',
#   'statement'],
#  ['instead',
#   'driving',
#   'job',
#   'wealth',
#   'away',
#   'america',
#   'become',
#   'world',
#   'great',
#   'magnet',
#   'innovation',
#   'job',
#   'creation'],
#  ['thank',
#   'law',
#   'enforcement',
#   'officer',
#   'across',
#   'america',
#   'lesm',
#   'maga',
#   'httpsinstagramcompbkxdnpcdzkx'],
#  ['never',
#   'fan',
#   'colin',
#   'powell',
#   'weak',
#   'understanding',
#   'weapon',
#   'mass',
#   'destruction',
#   'iraq',
#   'disaster',
#   'much',
#   'better'],
#  ['great',
#   'poll',
#   'nevada',
#   'thank',
#   'you',
#   'see',
#   'soon',
#   'maga',
#   'americafirsthttpwwwdonaldjtrumpcom'],
#  ['great',
#   'evening',
#   'canton',
#   'ohiothank',
#   'you',
#   'going',
#   'make',
#   'america',
#   'great',
#   'again',
#   'join',
#   'u',
#   'httpwwwdonaldjtrumpcom'],
#  ['thank',
#   'ohio',
#   'landed',
#   'canton',
#   'rally',
#   'civic',
#   'center',
#   'join',
#   '7pm',
#   'httpswwwdonaldjtrumpcomscheduleregistercantonoh'],
#  ['thank',
#   'florida',
#   'cant',
#   'wait',
#   'see',
#   'friday',
#   'miami',
#   'join',
#   'mehttpbitly2ciuuromiami'],
#  ['great', 'poll', 'florida', 'thank', 'you', 'imwithyou', 'americafirst'],
#  ['thank', 'ohio', 'see', 'tonight'],
#  ['russia',
#   'took',
#   'crimea',
#   'socalled',
#   'obama',
#   'year',
#   'wouldnt',
#   'know',
#   'obama',
#   'get',
#   'free',
#   'pas'],
#  ['isnt',
#   'president',
#   'obama',
#   'working',
#   'instead',
#   'campaigning',
#   'hillary',
#   'clinton'],
#  ['got',
#   'back',
#   'asheville',
#   'north',
#   'carolina',
#   'massive',
#   'rally',
#   'spirit',
#   'crowd',
#   'unbelievable',
#   'thank',
#   'you',
#   'maga'],
#  ['stopped', 'trumpdc', 'thank', 'tremendous', 'men', 'woman', 'hard', 'work'],
#  ['seriously',
#   'failing',
#   'nytimes',
#   'despite',
#   'much',
#   'winning',
#   'poll',
#   'number',
#   'soon',
#   'put',
#   'first',
#   'place',
#   'writes',
#   'dishonest',
#   'hit'],
#  ['hillary',
#   'clinton',
#   '47',
#   'moment',
#   'terrible',
#   'thing',
#   'said',
#   'many',
#   'great',
#   'american'],
#  ['hillary',
#   'said',
#   'horrible',
#   'thing',
#   'supporter',
#   'many',
#   'supporter',
#   'never',
#   'vote',
#   'me',
#   'still',
#   'respect',
#   'all'],
#  ['really',
#   'sad',
#   'republican',
#   'would',
#   'allow',
#   'used',
#   'clinton',
#   'ad',
#   'lindsey',
#   'graham',
#   'romney',
#   'flake',
#   'sas',
#   'supreme',
#   'court',
#   'remember'],
#  ['wow',
#   'hillary',
#   'clinton',
#   'insulting',
#   'supporter',
#   'million',
#   'amazing',
#   'hard',
#   'working',
#   'people',
#   'think',
#   'cost',
#   'poll'],
#  ['missouri',
#   'today',
#   'melania',
#   'funeral',
#   'wonderful',
#   'truly',
#   'respected',
#   'woman',
#   'phyllis',
#   's'],
#  ['thank',
#   'ohio',
#   'together',
#   'make',
#   'america',
#   'great',
#   'againhttpwwwdonaldjtrumpcom'],
#  ['great',
#   'honor',
#   'endorsed',
#   'popular',
#   'successful',
#   'govgilmore',
#   'va',
#   'state',
#   'much',
#   'want',
#   'winthx',
#   'jim'],
#  ['make', 'america', 'great', 'againamericafirst', 'imwithyou'],
#  ['cnn',
#   'unwatchable',
#   'news',
#   'fiction',
#   'theyare',
#   'disgrace',
#   'broadcasting',
#   'industry',
#   'arm',
#   'clinton',
#   'campaign'],
#  ['documentary',
#   'cnn',
#   'aired',
#   'total',
#   'waste',
#   'time',
#   'dont',
#   'even',
#   'know',
#   'many',
#   'people',
#   'spoke',
#   'me',
#   'joke'],
#  ['final',
#   'poll',
#   'result',
#   'nbc',
#   'last',
#   'night',
#   'commanderinchief',
#   'forum',
#   'thank',
#   'you',
#   'imwithyou',
#   'maga'],
#  ['wasnt',
#   'matt',
#   'lauer',
#   'hurt',
#   'hillary',
#   'last',
#   'night',
#   'dumb',
#   'answer',
#   'email',
#   'veteran',
#   'said',
#   'jail'],
#  ['poll',
#   'result',
#   'last',
#   'night',
#   'commanderinchief',
#   'forum',
#   'americafirst',
#   'trumptrain'],
#  ['hillary',
#   'clinton',
#   'answered',
#   'email',
#   'question',
#   'differently',
#   'last',
#   'night',
#   'past',
#   'totally',
#   'confused',
#   'unfit',
#   'serve',
#   'potus'],
#  ['hillary',
#   'gave',
#   'disastrous',
#   'news',
#   'conference',
#   'tarmac',
#   'make',
#   'poor',
#   'performance',
#   'last',
#   'night',
#   'shes',
#   'decimated',
#   'medium'],
#  ['rough', 'night', 'hillary', 'clinton', 'abc', 'news'],
#  ['thank', 'america', 'great', 'commanderinchiefforum', 'poll'],
#  ['thank',
#   'fantastic',
#   'veteran',
#   'review',
#   'poll',
#   'almost',
#   'everyone',
#   'commanderinchief',
#   'presentation',
#   'great',
#   'nice'],
#  ['thank',
#   'peter',
#   'elected',
#   'think',
#   'big',
#   'country',
#   'never',
#   'let',
#   'american',
#   'people',
#   'down',
#   'americafirsthttpswwwwashingtonpostcomopinionspeterthieltrumphastaughtusthisyearsmostimportantpoliticallesson2016090684df8182738c11e68149b8d05321db62storyhtmlpostshare541473247265202tidsstw'],
#  ['wow',
#   'thank',
#   'pensacola',
#   'fl',
#   'see',
#   'friday',
#   '7pm',
#   'join',
#   'mehttpbitly2ciou6wflorida'],
#  ['lead',
#   'hillary',
#   'clinton',
#   '19',
#   'point',
#   'among',
#   'military',
#   'veteran',
#   'voter',
#   'poll',
#   'americafirst',
#   'magahttpmwashingtontimescomnews2016sep7donaldtrumpleadshillaryclinton19pointsamong'],
#  ['thank',
#   'amazing',
#   'military',
#   'family',
#   'service',
#   'member',
#   'veteran',
#   'imwithyou'],
#  ['thank', 'you', 'votetrump', 'imwithyou'],
#  ['mainstream',
#   'medium',
#   'never',
#   'covered',
#   'hillary',
#   'massive',
#   'hackingor',
#   'coughing',
#   'attack',
#   'yet',
#   '1',
#   'trending',
#   'whats',
#   'up'],
#  ['thank', 'you', 'americafirst'],
#  ['china',
#   'wouldnt',
#   'provide',
#   'red',
#   'carpet',
#   'stairway',
#   'air',
#   'force',
#   'one',
#   'philippine',
#   'president',
#   'call',
#   'obama',
#   'son',
#   'whore',
#   'terrible'],
#  ['truly',
#   'great',
#   'phyllis',
#   'schlafly',
#   'honored',
#   'strong',
#   'endorsement',
#   'president',
#   'passed',
#   'away',
#   '92',
#   'special'],
#  ['heading', 'youngstown', 'ohio', 'great', 'poll', 'americafirst'],
#  ['believe',
#   'chinese',
#   'would',
#   'give',
#   'obama',
#   'proper',
#   'stairway',
#   'get',
#   'plane',
#   'fight',
#   'tarmachttpnypostcom20160903thisisourcountrytempersflareasobamaarrivesinchina'],
#  ['president',
#   'obama',
#   'putin',
#   'fail',
#   'reach',
#   'deal',
#   'syria',
#   'else',
#   'new',
#   'obama',
#   'natural',
#   'deal',
#   'maker',
#   'make',
#   'bad',
#   'deal'],
#  ['lyin',
#   'hillary',
#   'clinton',
#   'told',
#   'fbi',
#   'know',
#   'c',
#   'marking',
#   'document',
#   'stood',
#   'classified',
#   'happening'],
#  ['africanamerican',
#   'community',
#   'democrat',
#   'failed',
#   'fifty',
#   'year',
#   'high',
#   'crime',
#   'poor',
#   'school',
#   'job',
#   'fix',
#   'it',
#   'vote'],
#  ['poll',
#   'close',
#   'crooked',
#   'hillary',
#   'getting',
#   'bed',
#   'campaign',
#   'tomorrowwhy',
#   'hammer',
#   '13',
#   'device',
#   'acidwash',
#   'email'],
#  ['wow',
#   'failing',
#   'nytimes',
#   'reported',
#   'properly',
#   'crookeds',
#   'fbi',
#   'release',
#   'back',
#   'pack',
#   'longer',
#   'credible',
#   'source'],
#  ['cnn',
#   'disgusting',
#   'bias',
#   'hard',
#   'time',
#   'promoting',
#   'crooked',
#   'hillary',
#   'light',
#   'new',
#   'email',
#   'scandal'],
#  ['great',
#   'visit',
#   'detroit',
#   'church',
#   'fantastic',
#   'reception',
#   'cnn',
#   'talk',
#   'small',
#   'protest',
#   'outside',
#   'inside',
#   'large',
#   'wonderful',
#   'crowd'],
#  ['thank',
#   'great',
#   'faith',
#   'ministry',
#   'international',
#   'bishop',
#   'wayne',
#   't',
#   'jackson',
#   'detroithttpwwwsnappytvcomtc2727709'],
#  ['great',
#   'new',
#   'poll',
#   'iowa',
#   'thank',
#   'youmakeamericagreatagain',
#   'imwithyou'],
#  ['visited',
#   'tower',
#   'campaign',
#   'headquarters',
#   'last',
#   'night',
#   'returning',
#   'ohio',
#   'arizona',
#   'packed',
#   'great',
#   'pro',
#   'win'],
#  ['people',
#   'surprised',
#   'ground',
#   'game',
#   'nov',
#   '8',
#   'army',
#   'volunteer',
#   'people',
#   'great',
#   'spirit',
#   'want',
#   'maga'],
#  ['promising',
#   'new',
#   'legacy',
#   'america',
#   'going',
#   'create',
#   'new',
#   'american',
#   'future',
#   'thank',
#   'ohio',
#   'imwithyou'],
#  ['poll', 'number', 'way', 'making', 'big', 'progress'],
#  ['thank',
#   'foxandfriends',
#   'great',
#   'review',
#   'speech',
#   'immigration',
#   'last',
#   'night',
#   'thank',
#   'also',
#   'great',
#   'people',
#   'arizona'],
#  ['mexico', 'pay', 'wall'],
#  ['administration',
#   'called',
#   'americafirst',
#   'imwithyouhttpwwwsnappytvcomtc2711850'],
#  ['great',
#   'trip',
#   'mexico',
#   'today',
#   'wonderful',
#   'leadership',
#   'high',
#   'quality',
#   'people',
#   'look',
#   'forward',
#   'next',
#   'meeting'],
#  ['hillary',
#   'clinton',
#   'didnt',
#   'go',
#   'louisiana',
#   'didnt',
#   'go',
#   'mexico',
#   'doesnt',
#   'drive',
#   'stamen',
#   'make',
#   'america',
#   'great',
#   'again'],
#  ['former',
#   'president',
#   'vicente',
#   'fox',
#   'railing',
#   'visit',
#   'mexico',
#   'today',
#   'also',
#   'invited',
#   'apologized',
#   'using',
#   'f',
#   'bomb'],
#  ['thank',
#   'washington',
#   'together',
#   'make',
#   'america',
#   'safe',
#   'great',
#   'again',
#   'imwithyou',
#   'americafirst'],
#  ['accepted',
#   'invitation',
#   'president',
#   'enrique',
#   'pena',
#   'nieto',
#   'mexico',
#   'look',
#   'much',
#   'forward',
#   'meeting',
#   'tomorrow'],
#  ['thank', 'north', 'carolina', 'maga'],
#  ['day',
#   'one',
#   'said',
#   'going',
#   'build',
#   'great',
#   'wall',
#   'southern',
#   'border',
#   'much',
#   'more',
#   'stop',
#   'illegal',
#   'immigration',
#   'watch',
#   'wednesday'],
#  ['repeal', 'replace', 'horrible', 'disaster', 'known', 'obamacare'],
#  ['africanamericans',
#   'seeing',
#   'bad',
#   'job',
#   'hillary',
#   'type',
#   'policy',
#   'management',
#   'done',
#   'innercities',
#   'want',
#   'trump'],
#  ['anyone',
#   'know',
#   'crooked',
#   'hillary',
#   'tried',
#   'hard',
#   'unable',
#   'pas',
#   'bar',
#   'exam',
#   'washington',
#   'dc',
#   'forced',
#   'go',
#   'elsewhere'],
#  ['making',
#   'major',
#   'speech',
#   'illegal',
#   'immigration',
#   'wednesday',
#   'great',
#   'state',
#   'arizona',
#   'big',
#   'crowd',
#   'looking',
#   'larger',
#   'venue'],
#  ['think',
#   'candidate',
#   'crooked',
#   'hillary',
#   'myself',
#   'release',
#   'detailed',
#   'medical',
#   'record',
#   'problem',
#   'so',
#   'hillary'],
#  ['today',
#   '53rd',
#   'anniversary',
#   'march',
#   'washington',
#   'today',
#   'honor',
#   'enduring',
#   'fight',
#   'justice',
#   'equality',
#   'opportunity'],
#  ['national',
#   'debt',
#   'january',
#   '2009',
#   '106',
#   'trillionaugust',
#   '2016',
#   '194',
#   'trillion'],
#  ['honor',
#   'amazing',
#   'root',
#   'family',
#   'join',
#   'iowa',
#   'inspired',
#   'courage',
#   'braveryhttpsamptwimgcomvd96463a2c8f542a38865065ba39beb30'],
#  ['condolence',
#   'dwyane',
#   'wade',
#   'family',
#   'loss',
#   'nykea',
#   'aldridge',
#   'thought',
#   'prayer'],
#  ['dwyane',
#   'wade',
#   'cousin',
#   'shot',
#   'killed',
#   'walking',
#   'baby',
#   'chicago',
#   'saying',
#   'africanamericans',
#   'vote',
#   'trump'],
#  ['diamondandsilk',
#   'crooked',
#   'hillary',
#   'getting',
#   'desperate',
#   'tv',
#   'bashing',
#   'trump',
#   'cnn',
#   'forgot',
#   'said',
#   'kkk',
#   'member',
#   'mentor'],
#  ['heroin',
#   'overdoses',
#   'taking',
#   'child',
#   'others',
#   'midwest',
#   'coming',
#   'southern',
#   'border',
#   'need',
#   'strong',
#   'border',
#   'wall'],
#  ['new',
#   'poll',
#   'join',
#   'movement',
#   'todayhttpwwwdonaldjtrumpcom',
#   'imwithyou'],
#  ['phoenix',
#   'arizona',
#   'wednesday',
#   'changing',
#   'venue',
#   'much',
#   'larger',
#   'one',
#   'demand',
#   'unreal',
#   'poll',
#   'looking',
#   'great',
#   'imwithyou'],
#  ['quickly',
#   'people',
#   'forget',
#   'crooked',
#   'hillary',
#   'called',
#   'africanamerican',
#   'youth',
#   'super',
#   'predator',
#   'apologized'],
#  ['proud',
#   'brought',
#   'subject',
#   'illegal',
#   'immigration',
#   'back',
#   'discussion',
#   'big',
#   'problem',
#   'countryi',
#   'solve'],
#  ['africanamericans',
#   'hispanic',
#   'lose',
#   'going',
#   'me',
#   'look',
#   'poverty',
#   'crime',
#   'educational',
#   'statistic',
#   'fix',
#   'it'],
#  ['crooked',
#   'hillary',
#   'never',
#   'able',
#   'solve',
#   'problem',
#   'poverty',
#   'education',
#   'safety',
#   'within',
#   'africanamerican',
#   'hispanic',
#   'community'],
#  ['hillary',
#   'clinton',
#   'need',
#   'address',
#   'racist',
#   'undertone',
#   '2008',
#   'campaign',
#   'flashbackfriday'],
#  ['hillary',
#   'clinton',
#   'know',
#   'make',
#   'speech',
#   'hit',
#   'me',
#   'policy',
#   'always',
#   'short',
#   'stamen',
#   'medium',
#   'give',
#   'pas'],
#  ['hrc',
#   'using',
#   'oldest',
#   'play',
#   'dem',
#   'playbook',
#   'policy',
#   'fail',
#   'left',
#   'wthis',
#   'one',
#   'tired',
#   'argumenthttpwwwsnappytvcomtc2673821'],
#  ['hillary',
#   'clinton',
#   'using',
#   'racebaiting',
#   'try',
#   'get',
#   'africanamerican',
#   'voter',
#   'know',
#   'talk',
#   'action'],
#  ['hillary',
#   'clinton',
#   'short',
#   'speech',
#   'pandering',
#   'worst',
#   'instinct',
#   'society',
#   'ashamed',
#   'herself'],
#  ['watched',
#   'recap',
#   'crookedhillarys',
#   'speech',
#   'short',
#   'lie',
#   'one',
#   'fearmongering'],
#  ['many',
#   'africanamerican',
#   'community',
#   'badly',
#   'poverty',
#   'crime',
#   'way',
#   'up',
#   'employment',
#   'job',
#   'way',
#   'fix',
#   'it',
#   'promise'],
#  ['poll',
#   'number',
#   'starting',
#   'look',
#   'good',
#   'leading',
#   'florida',
#   'cnn',
#   'arizona',
#   'big',
#   'jump',
#   'utah',
#   'number',
#   'rising',
#   'national',
#   'way',
#   'up',
#   'wow'],
#  ['thought', 'prayer', 'great', 'people', 'indiana', 'prevail'],
#  ['great',
#   'governor',
#   'mikepence',
#   'indiana',
#   'help',
#   'lead',
#   'relief',
#   'effort',
#   'tornado',
#   'struck',
#   'true',
#   'leadership'],
#  ['great', 'new', 'poll', 'florida', 'thank', 'you', 'makeamericagreatagain'],
#  ['thought',
#   'prayer',
#   'victim',
#   'family',
#   'affected',
#   'two',
#   'powerful',
#   'earthquake',
#   'italy',
#   'myanmar'],
#  ['thank', 'travis', 'county', 'texasmakeamericagreatagain'],
#  ['austin',
#   'texas',
#   'amazing',
#   'border',
#   'patrol',
#   'agent',
#   'let',
#   'down',
#   'httpsinstagramcompbjdya79dxof'],
#  ['president',
#   'obama',
#   'gone',
#   'louisiana',
#   'day',
#   'ago',
#   'instead',
#   'golfing',
#   'little',
#   'late'],
#  ['reported',
#   'virtually',
#   'everyone',
#   'fact',
#   'medium',
#   'pile',
#   'worst',
#   'american',
#   'political',
#   'history'],
#  ['anncoulters',
#   'new',
#   'book',
#   'trust',
#   'come',
#   'tomorrow',
#   'people',
#   'saying',
#   'terrific',
#   'knowing',
#   'ann',
#   'sure',
#   'is'],
#  ['leaving',
#   'akron',
#   'ohio',
#   'packed',
#   'rally',
#   'amazing',
#   'people',
#   'going',
#   'texas'],
#  ['great',
#   'meeting',
#   'active',
#   'retired',
#   'law',
#   'enforcement',
#   'officer',
#   'fraternal',
#   'order',
#   'police',
#   'lodge',
#   'akron',
#   'ohio'],
#  ['day',
#   'thing',
#   'calm',
#   'down',
#   'ill',
#   'tell',
#   'real',
#   'story',
#   'joenbc',
#   'insecure',
#   'longtime',
#   'girlfriend',
#   'morningmika',
#   'two',
#   'clown'],
#  ['crooked',
#   'hillary',
#   'flooding',
#   'airwave',
#   'false',
#   'misleading',
#   'ad',
#   'paid',
#   'boss',
#   'wall',
#   'street',
#   'medium',
#   'protecting',
#   'her'],
#  ['drawing',
#   'big',
#   'enthusiastic',
#   'crowd',
#   'medium',
#   'refuse',
#   'show',
#   'discus',
#   'them',
#   'something',
#   'big',
#   'happening'],
#  ['together',
#   'going',
#   'make',
#   'america',
#   'safe',
#   'great',
#   'againhttpwwwbreitbartcom2016presidentialrace20160820latimespolltrumptakeshalfpointleadclinton'],
#  ['bring',
#   'america',
#   'together',
#   'one',
#   'country',
#   'united',
#   'american',
#   'common',
#   'purpose',
#   'common',
#   'dream',
#   'maga'],
#  ['catonglass',
#   '200000',
#   'new',
#   'follower',
#   'realdonaldtrump',
#   '10800000',
#   '11000000',
#   'last',
#   'ten',
#   'day',
#   'so',
#   'maga',
#   'alwaystrump'],
#  ['franklingraham',
#   'billynungesser',
#   'samaritanspurse',
#   'humbled',
#   'time',
#   'w',
#   'you',
#   'thought',
#   'prayer'],
#  ['one',
#   'nation',
#   'one',
#   'hurt',
#   'hurt',
#   'must',
#   'work',
#   'togetherto',
#   'lift',
#   'upstandwithlouisiana'],
#  ['whereshillary', 'sleeping'],
#  ['thank',
#   'michigan',
#   'movement',
#   'going',
#   'make',
#   'america',
#   'safe',
#   'great',
#   'again',
#   'trumppence16'],
#  ['thank',
#   'everyone',
#   'nice',
#   'comment',
#   'twitter',
#   'pundit',
#   'otherwise',
#   'speech',
#   'last',
#   'night'],
#  ['soon', 'calling', 'mr', 'brexit'],
#  ['going',
#   'make',
#   'government',
#   'people',
#   'againmakeamericagreatagain',
#   'imwithyouhttpsamptwimgcomv4586e62b3a35479da65df984df338175'],
#  ['repeal',
#   'replace',
#   'obamacare',
#   'caused',
#   'soaring',
#   'doubledigit',
#   'premium',
#   'increase',
#   'disasterhttpsamptwimgcomvddb1eaf1bdc544b3b090dc20494568f7'],
#  ['vote',
#   'hillary',
#   'clinton',
#   'vote',
#   'another',
#   'generation',
#   'poverty',
#   'high',
#   'crime',
#   'lost',
#   'opportunity',
#   'imwithyouhttpsamptwimgcomvd4fc15a4b04b48cc85a8fbdf61211602'],
#  ['another',
#   'health',
#   'insurer',
#   'pulling',
#   'back',
#   'due',
#   'persistent',
#   'financial',
#   'loss',
#   'obamacare',
#   'plan',
#   'beginninghttpwwwnbcnewscombusinessbusinessnewsaetnapullsbackobamacarehealthinsuranceplans2017n631656'],
#  ['clinton',
#   'refugee',
#   'plan',
#   'could',
#   'bring',
#   '620000',
#   'refugee',
#   'first',
#   'term',
#   'lifetime',
#   'cost',
#   '400',
#   'billion',
#   'httpwwwsessionssenategovpublicindexcfm20166clintonrefugeeplancouldbringin620000refugeesinfirsttermatlifetimecostofover400billion'],
#  ['certain',
#   'republican',
#   'lost',
#   'would',
#   'rather',
#   'save',
#   'face',
#   'fighting',
#   'see',
#   'ussupreme',
#   'court',
#   'get',
#   'proper',
#   'appointment',
#   'sad'],
#  ['stay',
#   'message',
#   'chant',
#   'always',
#   'trade',
#   'job',
#   'military',
#   'vet',
#   '2nd',
#   'a',
#   'repeal',
#   'ocare',
#   'border',
#   'etc',
#   'medium',
#   'misrepresents'],
#  ['always',
#   'personremain',
#   'true',
#   'selfthe',
#   'medium',
#   'want',
#   'change',
#   'would',
#   'dishonest',
#   'supporter',
#   'so'],
#  ['freedom',
#   'press',
#   'newspaper',
#   'others',
#   'allowed',
#   'say',
#   'write',
#   'whatever',
#   'want',
#   'even',
#   'completely',
#   'false'],
#  ['fighting',
#   'crooked',
#   'hillary',
#   'fighting',
#   'dishonest',
#   'corrupt',
#   'medium',
#   'government',
#   'protection',
#   'process',
#   'people',
#   'get',
#   'it'],
#  ['crooked',
#   'hillary',
#   'clinton',
#   'protected',
#   'medium',
#   'talented',
#   'person',
#   'politician',
#   'dishonest',
#   'medium',
#   'refuse',
#   'expose'],
#  ['rally',
#   'covered',
#   'properly',
#   'medium',
#   'never',
#   'discus',
#   'real',
#   'message',
#   'never',
#   'show',
#   'crowd',
#   'size',
#   'enthusiasm'],
#  ['disgusting',
#   'corrupt',
#   'medium',
#   'covered',
#   'honestly',
#   'didnt',
#   'put',
#   'false',
#   'meaning',
#   'word',
#   'say',
#   'would',
#   'beating',
#   'hillary',
#   '20'],
#  ['failing',
#   'nytimes',
#   'never',
#   'spoke',
#   'me',
#   'keep',
#   'saying',
#   'saying',
#   'adviser',
#   'change',
#   'false',
#   'amnever',
#   'said'],
#  ['failing',
#   'nytimes',
#   'talk',
#   'anonymous',
#   'source',
#   'meeting',
#   'never',
#   'happened',
#   'reporting',
#   'fiction',
#   'medium',
#   'protects',
#   'hillary'],
#  ['confirmation',
#   'one',
#   'reason',
#   'crooked',
#   'h',
#   'wanted',
#   'sure',
#   'nobody',
#   'saw',
#   'email',
#   'payforplay',
#   'run',
#   'pres'],
#  ['truly',
#   'enjoying',
#   'running',
#   'president',
#   'people',
#   'country',
#   'amazing',
#   'great',
#   'number',
#   'november',
#   '8th'],
#  ['failing',
#   'nytimes',
#   'become',
#   'newspaper',
#   'fiction',
#   'story',
#   'always',
#   'quote',
#   'nonexistent',
#   'unnamed',
#   'source',
#   'dishonest'],
#  ['thank', 'erie', 'pennsylvania', 'together', 'makeamericagreatagain'],
#  ['isi',
#   'gained',
#   'tremendous',
#   'strength',
#   'hillary',
#   'clinton',
#   'term',
#   'secretary',
#   'state',
#   'dishonest',
#   'medium',
#   'report',
#   'fact'],
#  ['love',
#   'watching',
#   'poor',
#   'pathetic',
#   'people',
#   'pundit',
#   'television',
#   'working',
#   'hard',
#   'seriously',
#   'try',
#   'figure',
#   'out',
#   'cant'],
#  ['massive',
#   'tax',
#   'increase',
#   'necessary',
#   'fund',
#   'crooked',
#   'hillary',
#   'clinton',
#   'agenda',
#   'terrible',
#   'boring',
#   'rollout',
#   'yesterday'],
#  ['rating',
#   'challenged',
#   'cnn',
#   'report',
#   'seriously',
#   'call',
#   'president',
#   'obama',
#   'clinton',
#   'founder',
#   'isi',
#   'mvp',
#   'dont',
#   'get',
#   'sarcasm'],
#  ['elsolarverde',
#   'corrupt',
#   'medium',
#   'creats',
#   'controversy',
#   'avoid',
#   'issue',
#   'hillaryclinton'],
#  ['surprise',
#   'constant',
#   'phony',
#   'reporting',
#   'failing',
#   'cnn',
#   'turn',
#   'everyone',
#   'off',
#   'american',
#   'people',
#   'get',
#   'it',
#   'httpwwwadweekcomtvnewserscoreboardtuesdayaugust9301887'],
#  ['thank', 'fort', 'lauderdale', 'florida', 'makeamericagreatagain'],
#  ['great',
#   'job',
#   'today',
#   'nypd',
#   'protecting',
#   'people',
#   'saving',
#   'climber'],
#  ['reuters',
#   'announced',
#   'secret',
#   'service',
#   'never',
#   'spoke',
#   'campaign',
#   'made',
#   'story',
#   'cnn',
#   'hoax',
#   'totally',
#   'dishonest'],
#  ['thought',
#   'prayer',
#   'two',
#   'police',
#   'officer',
#   'shot',
#   'sebastian',
#   'county',
#   'arkansas',
#   'lesm'],
#  ['dbongino',
#   'fantastic',
#   'defending',
#   'second',
#   'amendment',
#   'last',
#   'night',
#   'cnn',
#   'lemon',
#   'lightweight',
#   'dumb',
#   'rock'],
#  ['medium',
#   'desperate',
#   'distract',
#   'clinton',
#   'anti2a',
#   'stance',
#   'said',
#   'pro2a',
#   'citizen',
#   'must',
#   'organize',
#   'get',
#   'vote',
#   'save',
#   'constitution'],
#  ['medium',
#   'going',
#   'talk',
#   'hillary',
#   'policy',
#   'gotten',
#   'people',
#   'killed',
#   'like',
#   'libya',
#   'open',
#   'border',
#   'maybe',
#   'email'],
#  ['thank', 'wilmington', 'north', 'carolinamakeamericagreatagain'],
#  ['running',
#   'washington',
#   'insider',
#   'like',
#   'republican',
#   'primary',
#   'people',
#   'made',
#   'u',
#   'mess'],
#  ['detroit',
#   'today',
#   'wonderful',
#   'quick',
#   'stop',
#   'ohio',
#   'meet',
#   'great',
#   'supporter',
#   'got',
#   'back',
#   'home'],
#  ['many',
#   'people',
#   'saying',
#   'iranian',
#   'killed',
#   'scientist',
#   'helped',
#   'u',
#   'hillary',
#   'clinton',
#   'hacked',
#   'email'],
#  ['thank', 'newthttpstwittercomnewtgingrichstatus762739520567738368'],
#  ['icymi',
#   'medium',
#   'apologize',
#   'trumphttpwwwthegatewaypunditcom201608willmediaapologizetrumpmothercryingbabyrallyspeaks'],
#  ['michael',
#   'morell',
#   'lightweight',
#   'former',
#   'acting',
#   'director',
#   'cia',
#   'man',
#   'made',
#   'serious',
#   'bad',
#   'call',
#   'total',
#   'clinton',
#   'flunky'],
#  ['medium',
#   'going',
#   'crazy',
#   'totally',
#   'distort',
#   'many',
#   'thing',
#   'purpose',
#   'crimea',
#   'nuclear',
#   'baby',
#   'much',
#   'more',
#   'dishonest'],
#  ['see',
#   'mayor',
#   'stephanie',
#   'rawlingsblake',
#   'baltimore',
#   'pushing',
#   'crooked',
#   'hard',
#   'look',
#   'job',
#   'done',
#   'baltimore',
#   'joke'],
#  ['larrykudlow',
#   'middleclass',
#   'growth',
#   'candidatehttpwwwcnbccom20160806kudlowdonaldtrumpisthemiddleclassgrowthcandidatehtml'],
#  ['running',
#   'crooked',
#   'hillary',
#   'clinton',
#   'running',
#   'dishonest',
#   'totally',
#   'biased',
#   'medium',
#   'win'],
#  ['heading',
#   'new',
#   'hampshire',
#   'talking',
#   'hillary',
#   'saying',
#   'brain',
#   'short',
#   'circuited',
#   'thing'],
#  ['anybody',
#   'whose',
#   'mind',
#   'short',
#   'circuit',
#   'fit',
#   'president',
#   'look',
#   'word',
#   'brainwashed'],
#  ['crooked',
#   'hillary',
#   'said',
#   'loudly',
#   'world',
#   'see',
#   'short',
#   'circuited',
#   'answering',
#   'question',
#   'email',
#   'dangerous'],
#  ['hillary',
#   'clinton',
#   'badly',
#   'criticized',
#   'poor',
#   'performance',
#   'answering',
#   'question',
#   'let',
#   'u',
#   'see',
#   'happens'],
#  ['right',
#   'violent',
#   'crime',
#   'rise',
#   'major',
#   'citieshttpswwwwashingtonpostcomopinionstrumpisrightaboutviolentcrimeitsontheriseinmajorcities201608053cf6b55e5b1111e69aee8075993d73a2storyhtml'],
#  ['thank',
#   'green',
#   'bay',
#   'wisconsin',
#   'governor',
#   'mikepence',
#   'back',
#   'soon',
#   'trumppence16',
#   'maga'],
#  ['dont',
#   'let',
#   'hillary',
#   'clinton',
#   'againtrumppence16httpsamptwimgcomv42d9c3c3e9244a5bb8a9540ec3d21654'],
#  ['plane',
#   'saw',
#   'television',
#   'hostage',
#   'plane',
#   'geneva',
#   'switzerland',
#   'plane',
#   'carrying',
#   '400',
#   'million',
#   'cash',
#   'going',
#   'iran'],
#  ['president',
#   'obama',
#   'refuse',
#   'answer',
#   'question',
#   'iran',
#   'terror',
#   'funding',
#   'wont',
#   'dodge',
#   'question',
#   'president',
#   'httpntknetworkcomobamaspends7minutesdodgingonwhetheriranwilluse400milliontofundterrorism'],
#  ['obamas',
#   'disastrous',
#   'judgment',
#   'gave',
#   'u',
#   'isi',
#   'rise',
#   'iran',
#   'worst',
#   'economic',
#   'number',
#   'since',
#   'great',
#   'depression'],
#  ['president', 'obama', 'ask', 'dnc', 'rigged', 'election', 'bernie'],
#  ['happy',
#   '226th',
#   'birthday',
#   'united',
#   'state',
#   'coast',
#   'guard',
#   'thank',
#   'uscg',
#   'coastguardday'],
#  ['thank',
#   'amazing',
#   'law',
#   'enforcement',
#   'officer',
#   'today',
#   'daytona',
#   'beach',
#   'florida',
#   'lesm',
#   'maga'],
#  ['incompetent',
#   'secretary',
#   'state',
#   'hillary',
#   'clinton',
#   'one',
#   'started',
#   'talk',
#   'give',
#   '400',
#   'million',
#   'dollar',
#   'cash',
#   'iran',
#   'scandal'],
#  ['great',
#   'unity',
#   'campaign',
#   'perhaps',
#   'greater',
#   'ever',
#   'before',
#   'want',
#   'thank',
#   'everyone',
#   'tremendous',
#   'support',
#   'beat',
#   'crooked',
#   'h'],
#  ['president',
#   'obama',
#   'go',
#   'perhaps',
#   'worst',
#   'president',
#   'history',
#   'united',
#   'state'],
#  ['washington',
#   'post',
#   'call',
#   'crookedhillary',
#   'really',
#   'is',
#   'pathological',
#   'liar',
#   'watch',
#   'nose',
#   'grow'],
#  ['great',
#   'afternoon',
#   'ohio',
#   'great',
#   'evening',
#   'pennsylvania',
#   'departing',
#   'now',
#   'see',
#   'tomorrow',
#   'virginia'],
#  ['leaving',
#   'mechanicsburg',
#   'pa',
#   'incredible',
#   'crowd',
#   'enthusiastic',
#   'back',
#   'soon',
#   'maga'],
#  ['cnn',
#   'segment',
#   'hillary',
#   'plan',
#   'increase',
#   'syrian',
#   'refugee',
#   '550',
#   'much',
#   'cost'],
#  ['hillary',
#   'clinton',
#   'raked',
#   'money',
#   'regime',
#   'horribly',
#   'oppress',
#   'woman',
#   'gay',
#   'refuse',
#   'speak',
#   'radical',
#   'islam'],
#  ['hillary',
#   'whose',
#   'decision',
#   'led',
#   'death',
#   'many',
#   'accepted',
#   'business',
#   'linked',
#   'isi',
#   'silence',
#   'cnnhttpwwwthegatewaypunditcom201608wikileakshillary'],
#  ['crooked',
#   'hillary',
#   'clinton',
#   '100',
#   'owned',
#   'donor',
#   'imwithyou',
#   'maga'],
#  ['thank', 'oklahoma', 'virginia', 'makeamericagreatagain', 'imwithyou'],
#  ['people',
#   'believe',
#   'cnn',
#   'day',
#   'almost',
#   'little',
#   'believe',
#   'hillarythats',
#   'really',
#   'saying',
#   'something'],
#  ['cnn',
#   'send',
#   'camera',
#   'border',
#   'show',
#   'massive',
#   'unreported',
#   'crisis',
#   'unfolding',
#   'worried',
#   'hurt',
#   'hillary'],
#  ['see',
#   'story',
#   'cnn',
#   'clinton',
#   'foundation',
#   'corruption',
#   'hillary',
#   'payforplay',
#   'state',
#   'department'],
#  ['cnn',
#   'soon',
#   'least',
#   'trusted',
#   'name',
#   'news',
#   'continue',
#   'press',
#   'shop',
#   'hillary',
#   'clinton'],
#  ['story',
#   'mr',
#   'khan',
#   'place',
#   'interview',
#   'rather',
#   'radical',
#   'islamic',
#   'terrorism',
#   'u',
#   'get',
#   'smart'],
#  ['wow',
#   'unbelievable',
#   'distorted',
#   'onesided',
#   'biased',
#   'medium',
#   'u',
#   'failing',
#   'nytimes',
#   'joke',
#   'cnn',
#   'laughable'],
#  ['realjameswoods',
#   'without',
#   'absolutely',
#   'owning',
#   'liberal',
#   'medium',
#   'hillaryclinton',
#   'wouldnt',
#   'stand',
#   'chance',
#   'voterfraud',
#   'msm',
#   'hope'],
#  ['dishonest',
#   'medium',
#   'fawning',
#   'democratic',
#   'convention',
#   'wonder',
#   'why',
#   'then',
#   'speech',
#   'million',
#   'viewer',
#   'crooked',
#   'h'],
#  ['viciously',
#   'attacked',
#   'mr',
#   'khan',
#   'democratic',
#   'convention',
#   'allowed',
#   'respond',
#   'hillary',
#   'voted',
#   'iraq',
#   'war',
#   'me'],
#  ['captain',
#   'khan',
#   'killed',
#   '12',
#   'year',
#   'ago',
#   'hero',
#   'radical',
#   'islamic',
#   'terror',
#   'weakness',
#   'leader',
#   'eradicate',
#   'it'],
#  ['nielson',
#   'medium',
#   'research',
#   'final',
#   'number',
#   'acceptance',
#   'speech',
#   '322',
#   'million',
#   'clinton',
#   '278',
#   'million',
#   'thank',
#   'you'],
#  ['thank',
#   'television',
#   'viewer',
#   'made',
#   'speech',
#   'republican',
#   'national',
#   'convention',
#   '1',
#   'crooked',
#   'hillary',
#   'dems'],
#  ['wow',
#   'nato',
#   'top',
#   'commander',
#   'announced',
#   'agrees',
#   'alliance',
#   'member',
#   'must',
#   'pay',
#   'bill',
#   'general',
#   'like'],
#  ['crookeds',
#   'stop',
#   'johnstown',
#   'pennsylvania',
#   'job',
#   'absolutely',
#   'decimated',
#   'dumb',
#   'politician',
#   'drew',
#   'le',
#   '200',
#   'bill',
#   'vp'],
#  ['crookedhillary',
#   'obamas',
#   'third',
#   'term',
#   'would',
#   'terrible',
#   'news',
#   'economic',
#   'growth',
#   'seen',
#   'below'],
#  ['turned',
#   'meeting',
#   'charles',
#   'david',
#   'koch',
#   'much',
#   'better',
#   'meet',
#   'puppet',
#   'politics',
#   'much',
#   'better'],
#  ['crooked',
#   'hillary',
#   'clinton',
#   'soft',
#   'crime',
#   'support',
#   'open',
#   'border',
#   'want',
#   'massive',
#   'tax',
#   'hike',
#   'formula',
#   'disaster'],
#  ['violent',
#   'crime',
#   'rising',
#   'across',
#   'united',
#   'state',
#   'yet',
#   'dnc',
#   'convention',
#   'ignored',
#   'it',
#   'crime',
#   'reduction',
#   'one',
#   'top',
#   'priority'],
#  ['american',
#   'homeownership',
#   'rate',
#   'q2',
#   '2016',
#   '629',
#   'lowest',
#   'rate',
#   '51yrs',
#   'bring',
#   'back',
#   'american',
#   'dream'],
#  ['patrioticpepe',
#   'unite',
#   'america',
#   'fix',
#   'obamas',
#   'mistake',
#   'trump2016'],
#  ['usual',
#   'hillary',
#   'dems',
#   'trying',
#   'rig',
#   'debate',
#   '2',
#   'major',
#   'nfl',
#   'game',
#   'last',
#   'time',
#   'w',
#   'bernie',
#   'unacceptable'],
#  ['crookedhillary', 'job', 'application'],
#  ['hillary',
#   'clinton',
#   'given',
#   'national',
#   'security',
#   'briefing',
#   'lose',
#   'cannon',
#   'extraordinarily',
#   'bad',
#   'judgement',
#   'insticts'],
#  ['thank',
#   'amazing',
#   'law',
#   'enforcement',
#   'officer',
#   'coloradomakeamericagreatagain',
#   'lesm'],
#  ['bernie', 'sander', 'really', 'think', 'crooked', 'hillary', 'clinton'],
#  ['wow',
#   'campaign',
#   'hearing',
#   'bernie',
#   'supporter',
#   'never',
#   'support',
#   'crooked',
#   'hillary',
#   'sold',
#   'out',
#   'vp',
#   'pick'],
#  ['hillary', 'clinton', 'america', 'thing', 'get', 'worse', 'trumppence16'],
#  ['crooked',
#   'hillary',
#   'said',
#   'couldnt',
#   'handle',
#   'rough',
#   'tumble',
#   'political',
#   'campaign',
#   'reallyi',
#   'beat',
#   '16',
#   'people',
#   'beating',
#   'her'],
#  ['crooked',
#   'hillary',
#   'clinton',
#   'mentioned',
#   '22',
#   'time',
#   'long',
#   'boring',
#   'speech',
#   'many',
#   'statement',
#   'lie',
#   'fabrication'],
#  ['anncoulter',
#   'believe',
#   'science',
#   'dem',
#   'code',
#   'shutting',
#   'coal',
#   'mine',
#   'steel',
#   'plant',
#   'remaining',
#   'manufacturing'],
#  ['two',
#   'policeman',
#   'shot',
#   'san',
#   'diego',
#   'one',
#   'dead',
#   'getting',
#   'worse',
#   'people',
#   'want',
#   'law',
#   'order'],
#  ['crooked',
#   'hillary',
#   'clinton',
#   'made',
#   'fact',
#   'me',
#   'forgot',
#   'mention',
#   'many',
#   'problem',
#   'country',
#   'average',
#   'scream'],
#  ['one',
#   'worse',
#   'judgement',
#   'hillary',
#   'clinton',
#   'corruption',
#   'devastation',
#   'follows',
#   'wherever',
#   'go'],
#  ['hillary',
#   'war',
#   'middle',
#   'east',
#   'unleashed',
#   'destruction',
#   'terrorism',
#   'isi',
#   'across',
#   'world'],
#  ['hillary',
#   'vision',
#   'borderless',
#   'world',
#   'working',
#   'people',
#   'power',
#   'job',
#   'safety'],
#  ['hillary', 'never', 'reform', 'wall', 'street', 'owned', 'wall', 'street'],
#  ['way',
#   'life',
#   'threat',
#   'radical',
#   'islam',
#   'hillary',
#   'clinton',
#   'cannot',
#   'even',
#   'bring',
#   'say',
#   'word'],
#  ['hillary',
#   'refusal',
#   'mention',
#   'radical',
#   'islam',
#   'push',
#   '550',
#   'increase',
#   'refugee',
#   'proof',
#   'unfit',
#   'lead',
#   'country'],
#  ['median',
#   'household',
#   'income',
#   'middle',
#   'class',
#   'since',
#   'obama',
#   'took',
#   'office',
#   'go',
#   'clinton'],
#  ['vote',
#   'clintonkaine',
#   'vote',
#   'tpp',
#   'nafta',
#   'high',
#   'tax',
#   'radical',
#   'regulation',
#   'massive',
#   'influx',
#   'refugee'],
#  ['president',
#   'obama',
#   'spoke',
#   'last',
#   'night',
#   'world',
#   'doesnt',
#   'exist',
#   '70',
#   'people',
#   'think',
#   'country',
#   'going',
#   'wrong',
#   'direction',
#   'dnc'],
#  ['davidwohl',
#   'barack',
#   'offended',
#   'demand',
#   'nato',
#   'ally',
#   'pay',
#   'fair',
#   'share',
#   'demsinphilly'],
#  ['country',
#   'feel',
#   'great',
#   'already',
#   'million',
#   'wonderful',
#   'people',
#   'living',
#   'poverty',
#   'violence',
#   'despair'],
#  ['shooting',
#   'death',
#   'police',
#   'officer',
#   '78',
#   'year',
#   'must',
#   'restore',
#   'law',
#   'order',
#   'protect',
#   'great',
#   'law',
#   'enforcement',
#   'officer'],
#  ['thank', 'amazing', 'law', 'enforcement', 'officer', 'maga'],
#  ['great', 'new', 'poll', 'thank', 'youmakeamericagreatagain'],
#  ['russia',
#   'country',
#   'person',
#   'hillary',
#   'clinton',
#   '33000',
#   'illegally',
#   'deleted',
#   'email',
#   'perhaps',
#   'share',
#   'fbi'],
#  ['one',
#   'american',
#   'flag',
#   'massive',
#   'stage',
#   'democratic',
#   'national',
#   'convention',
#   'people',
#   'started',
#   'complainingthen',
#   'small',
#   'one',
#   'pathetic'],
#  ['bright',
#   'vice',
#   'president',
#   'joe',
#   'biden',
#   'stated',
#   'wanted',
#   'carpet',
#   'bomb',
#   'enemy',
#   'sorry',
#   'joe',
#   'ted',
#   'cruz'],
#  ['crooked',
#   'hillary',
#   'clinton',
#   'want',
#   'flood',
#   'country',
#   'syrian',
#   'immigrant',
#   'know',
#   'little',
#   'nothing',
#   'about',
#   'danger',
#   'massive',
#   'no'],
#  ['hopefully',
#   'violent',
#   'vicious',
#   'killing',
#   'isi',
#   'beloved',
#   'french',
#   'priest',
#   'causing',
#   'people',
#   'start',
#   'thinking',
#   'rationally',
#   'get',
#   'tough'],
#  ['democratic',
#   'convention',
#   'paid',
#   'zero',
#   'respect',
#   'great',
#   'police',
#   'law',
#   'enforcement',
#   'professional',
#   'country',
#   'recognition',
#   'sad'],
#  ['many',
#   'bernies',
#   'supporter',
#   'left',
#   'arena',
#   'bernie',
#   'go',
#   'home',
#   'go',
# ...
#   'long',
#   'hard'],
#  ['anncoulter',
#   'gop',
#   'trying',
#   'steal',
#   'nomination',
#   'winner',
#   'block',
#   'insurgent',
#   'catching',
#   '2',
#   'frontrunner',
#   'sander'],
#  ['theresacali',
#   'poll',
#   'show',
#   'lead',
#   'among',
#   'registered',
#   'republican',
#   'woman',
#   '44'],
#  ['great',
#   'honor',
#   'visit',
#   '911',
#   'memorial',
#   'museum',
#   'wife',
#   'melaniatrump',
#   'today',
#   'newyorkvalues'],
#  ['gene70', 'real', 'person', 'year'],
#  ['bernie',
#   'sander',
#   'say',
#   'hillary',
#   'clinton',
#   'unqualified',
#   'president',
#   'based',
#   'decision',
#   'making',
#   'ability',
#   'go',
#   'along',
#   'that'],
#  ['isnt',
#   'shame',
#   'person',
#   'far',
#   'delegate',
#   'many',
#   'million',
#   'vote',
#   'anyone',
#   'else',
#   'me',
#   'still',
#   'must',
#   'fight'],
#  ['lilrachiepoo',
#   'thank',
#   'you',
#   'mr',
#   'trump',
#   'personal',
#   'financial',
#   'sacrifice',
#   'journey',
#   'makeamericagreatagain'],
#  ['redneckgp',
#   'hater',
#   'there',
#   'stop',
#   'trashing',
#   'candidate',
#   'put',
#   'america',
#   'first',
#   'trump'],
#  ['kirstiealley',
#   'hello',
#   'boy',
#   'formal',
#   'endorsement',
#   'im',
#   'woman',
#   'last',
#   'checked',
#   'rudy',
#   'u',
#   'r',
#   'amazing'],
#  ['cam',
#   'report',
#   'rnc',
#   'received',
#   '1',
#   'million',
#   'postcard',
#   'far',
#   'get',
#   'info',
#   'ill',
#   'post',
#   'anncoulter',
#   'httptwittercomcampaigntrumpstatus718572490981646336photo1'],
#  ['nobody',
#   'beat',
#   'national',
#   'security',
#   'httpwwwnewsmaxcomnewsfrontnewsmaxfabriziopooldonaldtrump20160323id720556'],
#  ['look',
#   'like',
#   'right',
#   'nato',
#   'doubthttpforeignpolicycom20160406senatorsslamnatofreeridersincloseddoormeetingwithsecretarygeneral'],
#  ['ruokuk',
#   'glozee1',
#   'paulmanafort',
#   'cnn',
#   'danscavino',
#   'vote',
#   'save',
#   'west',
#   'dont',
#   'become',
#   'like',
#   'europe',
#   'wakeupamerica'],
#  ['great',
#   'new',
#   'york',
#   'catching',
#   'many',
#   'thing',
#   'remember',
#   'still',
#   'running',
#   'major',
#   'business',
#   'campaign',
#   'loving',
#   'it'],
#  ['dicristo13',
#   'let',
#   'policy',
#   'speech',
#   'immigration',
#   'economy',
#   'foreign',
#   'policy',
#   'nato'],
#  ['genie115', 'makeamericagreatagain', 'rt'],
#  ['ted',
#   'cruz',
#   'attacked',
#   'new',
#   'yorkers',
#   'new',
#   'york',
#   'value',
#   'dont',
#   'forget',
#   'httpswwwinstagramcompbd6skimghqt'],
#  ['unbelievable',
#   'evening',
#   'made',
#   'speech',
#   'front',
#   '17000',
#   'amazing',
#   'new',
#   'yorkers',
#   'bethpage',
#   'long',
#   'island',
#   'great',
#   'home'],
#  ['great',
#   'back',
#   'home',
#   'looking',
#   'forward',
#   'great',
#   'rally',
#   'tonight',
#   'bethpage',
#   'long',
#   'island'],
#  ['good',
#   'morning',
#   'wisconsin',
#   'poll',
#   'open',
#   'votetrump',
#   'today',
#   'makeamericagreatagainhttpbitly1vt2jbscavwi'],
#  ['foxnews',
#   'scottbaio',
#   'donaldtrump',
#   'guy',
#   'think',
#   'nerve',
#   'attack',
#   'fighthttpsamptwimgcomv4287e37db2b24e089b04cbad8d0c6617'],
#  ['leaving',
#   'superior',
#   'wisconsin',
#   'now',
#   'thank',
#   'you',
#   'trump2016',
#   'wiprimaryhttpswwwfacebookcomdonaldtrumpposts101568875100557250'],
#  ['wow',
#   'great',
#   'news',
#   'wisconsin',
#   'made',
#   'two',
#   'speech',
#   'big',
#   'one',
#   'coming',
#   'tonight',
#   'thank',
#   'youhttpstwittercomhowardkurtzstatus717058440942628864'],
#  ['interviewed',
#   'seanhannity',
#   'foxnews',
#   'wisconsin',
#   'tonight',
#   'wife',
#   'melania',
#   'join',
#   'entire',
#   'show'],
#  ['great',
#   'day',
#   'wisconsin',
#   'many',
#   'stop',
#   'many',
#   'great',
#   'people',
#   'melania',
#   'joining',
#   'monday',
#   'big',
#   'crowd',
#   'make',
#   'america',
#   'great',
#   'again'],
#  ['great',
#   'night',
#   'west',
#   'allis',
#   'wisconsin',
#   'thank',
#   'you',
#   'votetrumpwi',
#   'wiprimary',
#   'httpswwwfacebookcomdonaldtrumpposts101568838528007250'],
#  ['thank',
#   'miss',
#   'katies',
#   'dinermakeamericagreatagain',
#   'trump2016httpswwwfacebookcomdonaldtrumpposts101568819627207250'],
#  ['thank',
#   'new',
#   'york',
#   'pennsylvania',
#   'makeamericagreatagain',
#   'trump2016'],
#  ['gopjenna',
#   'dont',
#   'care',
#   'game',
#   'care',
#   'people',
#   'thats',
#   'exactly',
#   'people',
#   'love',
#   'much',
#   'trump2016'],
#  ['thank', 'you', 'trump2016', 'wiprimary'],
#  ['margee11',
#   'wisconsin',
#   'vote',
#   'smart',
#   'tedcruz',
#   'record',
#   'r',
#   'sealed',
#   'hiding',
#   'save',
#   'america',
#   'w'],
#  ['thank',
#   'eau',
#   'claire',
#   'wisconsin',
#   'votetrump',
#   'tuesday',
#   'april',
#   '5thmake',
#   'america',
#   'great',
#   'again'],
#  ['foxnews',
#   'ashamed',
#   'allowing',
#   'expert',
#   'explain',
#   'make',
#   'nuclear',
#   'attack'],
#  ['wisconsin',
#   'suffered',
#   'great',
#   'loss',
#   'job',
#   'trade',
#   'win',
#   'bad',
#   'thing',
#   'happening',
#   'u',
#   'rapidly',
#   'reversed'],
#  ['wisconsin',
#   'election',
#   'job',
#   'trade',
#   'immigration',
#   'big',
#   'factor',
#   'bring',
#   'job',
#   'back',
#   'home',
#   'make',
#   'great',
#   'deal'],
#  ['megynkelly',
#   'stopped',
#   'covering',
#   'show',
#   'rating',
#   'would',
#   'drop',
#   'like',
#   'rock',
#   'h',
#   'h',
#   'interview',
#   'ac360',
#   'beat',
#   'million'],
#  ['possible',
#   'megynkelly',
#   'cover',
#   'anyone',
#   'terrible',
#   'show',
#   'totally',
#   'misrepresents',
#   'word',
#   'position',
#   'bad'],
#  ['believe',
#   'ted',
#   'cruz',
#   'killing',
#   'country',
#   'trade',
#   'long',
#   'put',
#   'wisconsin',
#   'ad',
#   'talking',
#   'trade'],
#  ['must',
#   'build',
#   'great',
#   'wall',
#   'mexico',
#   'united',
#   'stateshttpwwwdailymailcouknewsarticle3518397momenttwodrugssmugglersfilmednewscrewsneakingusscalingarizonaborderfencehtml'],
#  ['1st',
#   'time',
#   'american',
#   'history',
#   'america',
#   '16500',
#   'border',
#   'patrol',
#   'agent',
#   'issue',
#   'presidential',
#   'primary',
#   'endorsementme',
#   'thank',
#   'you'],
#  ['national',
#   'border',
#   'patrol',
#   'council',
#   'nbpc',
#   'said',
#   'open',
#   'border',
#   'biggest',
#   'physical',
#   'economic',
#   'threat',
#   'facing',
#   'american',
#   'people'],
#  ['club',
#   'growth',
#   'said',
#   'ad',
#   '465',
#   'delegate',
#   'cruz',
#   'plus',
#   '143',
#   'delegate',
#   'kasich',
#   '739',
#   'delegate',
#   'try',
#   'again'],
#  ['club',
#   'growthwhich',
#   'asked',
#   '1000000',
#   'extortion',
#   'attempt',
#   'put',
#   'wisconsin',
#   'ad',
#   'incorrect',
#   'mathwhat',
#   'dumb',
#   'group'],
#  ['thank',
#   'you',
#   'america',
#   'trump2016makeamericagreatagain',
#   'httpbitly1rq7r0hgopnationalpoll'],
#  ['thank',
#   'you',
#   'wisconsin',
#   'votetrump',
#   'next',
#   'tuesday',
#   'april',
#   '5th',
#   'wiprimaryhttpbitly1rswyojvotetrumpwi'],
#  ['nice',
#   'meeting',
#   'reince',
#   'priebus',
#   'gop',
#   'looking',
#   'forward',
#   'bringing',
#   'party',
#   'together',
#   'happen'],
#  ['doctrine',
#   'peace',
#   'strength',
#   'trump2016',
#   'httpswwwfacebookcomdonaldtrumpposts10156866194350725'],
#  ['susanbirchfiel1',
#   'nothing',
#   'say',
#   'change',
#   'mind',
#   'woman',
#   'httpstwittercomcaroldestatus715345677409259520'],
#  ['gearssuxs',
#   'loudobbsnews',
#   'im',
#   'democrat',
#   'switch',
#   'republican',
#   'vote',
#   'primary',
#   'great'],
#  ['thank',
#   'appleton',
#   'wisconsinwiprimary',
#   'trump2016',
#   'httpswwwfacebookcomdonaldtrumpposts101568626756207250'],
#  ['congratulation',
#   'cnn',
#   'wisdom',
#   'pick',
#   'trump',
#   'makeamericagreatagain',
#   'trump2016'],
#  ['please',
#   'keep',
#   'thought',
#   'prayer',
#   'melissa',
#   'young',
#   'miss',
#   'wisconsin',
#   '2005httpwwwcnncom20160330politicstrumpmisswisconsinemotionalmomentindexhtmlsrtwcnn033016trumpmisswisconsinemotionalmoment0214pmstorylinklinkid22869280'],
#  ['thank',
#   'you',
#   'new',
#   'yorkmakeamericagreatagain',
#   'trump2016httpswwwfacebookcomdonaldtrumpposts101568614056907250'],
#  ['davidgregory',
#   'got',
#   'thrown',
#   'tv',
#   'nbc',
#   'fired',
#   'like',
#   'dog',
#   'cnn',
#   'nasty',
#   'me',
#   'nice'],
#  ['final',
#   's',
#   'announced',
#   'great',
#   'state',
#   'mo',
#   'win',
#   'new',
#   'certified',
#   's',
#   'show',
#   '365',
#   'vote',
#   'increase',
#   'least',
#   '12',
#   'delegate'],
#  ['reporter', 'touching', 'leave', 'news', 'conference', 'hand'],
#  ['victory',
#   'press',
#   'conference',
#   'over',
#   'allowed',
#   'grab',
#   'shout',
#   'question',
#   'press',
#   'charge'],
#  ['wow',
#   'corey',
#   'lewandowski',
#   'campaign',
#   'manager',
#   'decent',
#   'man',
#   'charged',
#   'assaulting',
#   'reporter',
#   'look',
#   'tapesnothing',
#   'there'],
#  ['million',
#   'voteshundreds',
#   'dels',
#   'cruz',
#   'kasich',
#   'yet',
#   'treated',
#   'properly',
#   'republican',
#   'party',
#   'rnc'],
#  ['wow',
#   'cnn',
#   'nothing',
#   'opponent',
#   'show',
#   'really',
#   'onesided',
#   'unfair',
#   'reporting',
#   'maybe',
#   'shouldnt',
#   'townhall',
#   'tonight'],
#  ['need',
#   'secure',
#   'border',
#   'asap',
#   'game',
#   'must',
#   'smart',
#   'tough',
#   'vigilant',
#   'make',
#   'america',
#   'great',
#   'make',
#   'america',
#   'strong',
#   'again'],
#  ['lyin',
#   'ted',
#   'already',
#   'beaten',
#   'debate',
#   'way',
#   'ahead',
#   'vote',
#   'delegate',
#   'focus',
#   'job',
#   'illegal',
#   'imm'],
#  ['detainee',
#   'released',
#   'gitmo',
#   'killed',
#   'american',
#   'socalled',
#   'leader',
#   'ever',
#   'learn'],
#  ['united',
#   'state',
#   'cannot',
#   'continue',
#   'make',
#   'bad',
#   'onesided',
#   'trade',
#   'deal',
#   'many',
#   'job',
#   'give',
#   'up',
#   'more'],
#  ['see',
#   'lyin',
#   'ted',
#   'even',
#   'dailybeast',
#   'fan',
#   'mine',
#   'say',
#   'story',
#   'came',
#   'rubio',
#   'trump'],
#  ['show',
#   'unfair',
#   'republican',
#   'primary',
#   'politics',
#   'be',
#   'state',
#   'louisiana',
#   'get',
#   'le',
#   'delegate',
#   'cruzlawsuit',
#   'coming'],
#  ['another',
#   'radical',
#   'islamic',
#   'attack',
#   'time',
#   'pakistan',
#   'targeting',
#   'christian',
#   'woman',
#   'child',
#   'least',
#   '67',
#   'dead400',
#   'injured',
#   'alone',
#   'solve'],
#  ['happy', 'easter', 'all', 'great', 'day'],
#  ['statement',
#   'nato',
#   'obsolete',
#   'disproportionately',
#   'expensive',
#   'unfair',
#   'u',
#   'now',
#   'finally',
#   'receiving',
#   'plaudit'],
#  ['remember',
#   'candidate',
#   'selffunding',
#   'given',
#   'little',
#   'credit',
#   'voter',
#   'bought',
#   'like',
#   'others'],
#  ['dont',
#   'believe',
#   'foxnews',
#   'poll',
#   'another',
#   'phony',
#   'hit',
#   'job',
#   'me',
#   'beat',
#   'hillary',
#   'clinton',
#   'easily',
#   'general',
#   'election'],
#  ['wisconsin',
#   'economy',
#   'poorly',
#   'like',
#   'everywhere',
#   'else',
#   'u',
#   'job',
#   'leaving',
#   'make',
#   'economy',
#   'strong',
#   'bring',
#   'job'],
#  ['nobody',
#   'protect',
#   'nation',
#   'like',
#   'j',
#   'trump',
#   'military',
#   'greatly',
#   'strengthened',
#   'border',
#   'strong',
#   'illegals',
#   'out'],
#  ['lyin',
#   'ted',
#   'cruz',
#   'trying',
#   'convince',
#   'prople',
#   'problem',
#   'national',
#   'enqwere',
#   'caused',
#   'me',
#   'nothing',
#   'story'],
#  ['press',
#   'going',
#   'way',
#   'convince',
#   'people',
#   'like',
#   'respect',
#   'woman',
#   'know',
#   'opposite'],
#  ['medium',
#   'woman',
#   'wow',
#   'tough',
#   'business',
#   'nobody',
#   'respect',
#   'woman',
#   'trump'],
#  ['tytan01',
#   'dear',
#   'cnn',
#   'quick',
#   'google',
#   'twitter',
#   'search',
#   '15000',
#   'woman',
#   'group',
#   'supporting',
#   'donaldtrump',
#   'stop',
#   'lying'],
#  ['top',
#   'suspect',
#   'paris',
#   'massacre',
#   'salah',
#   'abdeslam',
#   'also',
#   'knew',
#   'brussels',
#   'attack',
#   'longer',
#   'talking',
#   'weak',
#   'leader',
#   'ridiculous',
#   'law'],
#  ['wow',
#   'released',
#   '67',
#   'million',
#   'negative',
#   'ad',
#   'spent',
#   'me',
#   'still',
#   'number',
#   'one',
#   'lot'],
#  ['didnt',
#   'start',
#   'fight',
#   'lyinted',
#   'cruz',
#   'gq',
#   'cover',
#   'pic',
#   'melania',
#   'did',
#   'knew',
#   'pac',
#   'putting',
#   'hence',
#   'lyin',
#   'ted'],
#  ['big',
#   'federal',
#   'lawsuit',
#   'similar',
#   'certain',
#   'way',
#   'u',
#   'case',
#   'press',
#   'refuse',
#   'write',
#   'it',
#   'lostmonster',
#   'story'],
#  ['europe',
#   'u',
#   'must',
#   'immediately',
#   'stop',
#   'taking',
#   'people',
#   'syria',
#   'destruction',
#   'civilization',
#   'know',
#   'it',
#   'sad'],
#  ['announced',
#   'many',
#   '5000',
#   'isi',
#   'fighter',
#   'infiltrated',
#   'europe',
#   'also',
#   'many',
#   'u',
#   'told',
#   'so',
#   'alone',
#   'fix',
#   'problem'],
#  ['amazing',
#   'often',
#   'right',
#   'criticized',
#   'medium',
#   'illegal',
#   'immigration',
#   'take',
#   'oil',
#   'build',
#   'wall',
#   'muslim',
#   'nato'],
#  ['remember',
#   'recently',
#   'said',
#   'brussels',
#   'hell',
#   'hole',
#   'mess',
#   'failing',
#   'nytimes',
#   'wrote',
#   'critical',
#   'article',
#   'right'],
#  ['donvito08',
#   'picture',
#   'worth',
#   'thousand',
#   'word',
#   'lyingted',
#   'nevercruz',
#   'melaniatrump'],
#  ['make', 'america', 'great', 'again'],
#  ['think',
#   'jebs',
#   'endorsement',
#   'hurt',
#   'lyin',
#   'ted',
#   'jeb',
#   'spent',
#   '150000000',
#   'got',
#   'nothing',
#   'spent',
#   'fraction',
#   'first'],
#  ['best',
#   'far',
#   'fighting',
#   'terror',
#   'im',
#   'one',
#   'right',
#   'beginning',
#   'lyin',
#   'ted',
#   'others',
#   'copying',
#   'me'],
#  ['watched',
#   'hillary',
#   'deliver',
#   'prepackaged',
#   'speech',
#   'terror',
#   'shes',
#   'office',
#   'fighting',
#   'terror',
#   '20',
#   'year',
#   'look',
#   'are'],
#  ['low',
#   'energy',
#   'jeb',
#   'bush',
#   'endorsed',
#   'man',
#   'truly',
#   'hate',
#   'lyin',
#   'ted',
#   'cruz',
#   'honestly',
#   'cant',
#   'blame',
#   'jeb',
#   'drove',
#   'oblivion'],
#  ['lyin',
#   'ted',
#   'cruz',
#   'steal',
#   'foreign',
#   'policy',
#   'me',
#   'line',
#   'michael',
#   'douglas',
#   'another',
#   'dishonest',
#   'politician'],
#  ['lyin',
#   'ted',
#   'cruz',
#   'denied',
#   'anything',
#   'gq',
#   'model',
#   'photo',
#   'post',
#   'melania',
#   'thats',
#   'call',
#   'lyin',
#   'ted'],
#  ['hopefully',
#   'republican',
#   'party',
#   'come',
#   'together',
#   'big',
#   'win',
#   'november',
#   'paving',
#   'way',
#   'many',
#   'great',
#   'supreme',
#   'court',
#   'justice'],
#  ['much',
#   'bigger',
#   'win',
#   'anticipated',
#   'arizona',
#   'thank',
#   'you',
#   'never',
#   'forget'],
#  ['incompetent',
#   'hillary',
#   'despite',
#   'horrible',
#   'attack',
#   'brussels',
#   'today',
#   'want',
#   'border',
#   'weak',
#   'openand',
#   'let',
#   'muslim',
#   'flow',
#   'in',
#   'way'],
#  ['lyin',
#   'ted',
#   'cruz',
#   'used',
#   'picture',
#   'melania',
#   'gq',
#   'shoot',
#   'ad',
#   'careful',
#   'lyin',
#   'ted',
#   'spill',
#   'bean',
#   'wife'],
#  ['pres',
#   'obama',
#   'leave',
#   'baseball',
#   'game',
#   'cuba',
#   'immediately',
#   'get',
#   'home',
#   'washington',
#   'potus',
#   'serious',
#   'emergency',
#   'belongs'],
#  ['obama',
#   'others',
#   'weak',
#   'politically',
#   'correct',
#   'terror',
#   'group',
#   'forming',
#   'getting',
#   'stronger',
#   'shame'],
#  ['heart',
#   'prayer',
#   'go',
#   'victim',
#   'terrible',
#   'brussels',
#   'tragedy',
#   'madness',
#   'must',
#   'stopped',
#   'stop',
#   'it'],
#  ['watch',
#   'clip',
#   'earlier',
#   'year',
#   'time',
#   'time',
#   'right',
#   'terrorism',
#   'time',
#   'get',
#   'tough',
#   'httpswwwinstagramcompbdqvbinghwm'],
#  ['proven',
#   'far',
#   'correct',
#   'terrorism',
#   'anybody',
#   'even',
#   'close',
#   'hopefully',
#   'az',
#   'ut',
#   'voting',
#   'today'],
#  ['make', 'america', 'great', 'again'],
#  ['president',
#   'obama',
#   'look',
#   'sound',
#   'ridiculous',
#   'making',
#   'speech',
#   'cuba',
#   'especially',
#   'shadow',
#   'brussels',
#   'treated',
#   'badly'],
#  ['remember',
#   'beautiful',
#   'safe',
#   'place',
#   'brussels',
#   'wa',
#   'anymore',
#   'different',
#   'world',
#   'u',
#   'must',
#   'vigilant',
#   'smart'],
#  ['barrong510', 'medium', 'corrupt', 'people', 'fighting', 'you'],
#  ['wow',
#   'president',
#   'obama',
#   'landed',
#   'cuba',
#   'big',
#   'deal',
#   'raul',
#   'castro',
#   'wasnt',
#   'even',
#   'greet',
#   'him',
#   'greeted',
#   'pope',
#   'others',
#   'respect'],
#  ['highly',
#   'overrated',
#   'anchor',
#   'megynkelly',
#   'allowed',
#   'constantly',
#   'say',
#   'bad',
#   'thing',
#   'show',
#   'cant',
#   'fight',
#   'back',
#   'wrong'],
#  ['protester',
#   'blocked',
#   'major',
#   'highway',
#   'yesterday',
#   'delaying',
#   'entry',
#   'rally',
#   'arizona',
#   'hour',
#   'medium',
#   'blame',
#   'supporter'],
#  ['horrendous',
#   'protester',
#   'scream',
#   'curse',
#   'punch',
#   'shut',
#   'roadsdoors',
#   'rally',
#   'never',
#   'blamed',
#   'medium',
#   'sad'],
#  ['rally',
#   'utah',
#   'arizona',
#   'great',
#   'tremendous',
#   'crowd',
#   'spirit',
#   'returned',
#   'going',
#   'back',
#   'soon'],
#  ['jojo2foxy',
#   'afraid',
#   'anything',
#   'anyone',
#   'thats',
#   'president',
#   'usa',
#   'need',
#   'unite',
#   'u',
#   'knock',
#   'sock',
#   'enemy'],
#  ...]

# %% [markdown]
# ### Preparing Document-Term Matrix

# %%
# Creating the term dictionary of our courpus, where every unique term is assigned an index. 
dictionary = corpora.Dictionary(doc_clean)

# Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]

# %% [markdown]
# ### Running LDA Model

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# %%
# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=3, id2word = dictionary, passes=5)

# %%
print(ldamodel.print_topics(num_topics=10, num_words=10))
