# %% [markdown]
# # Political Social Media Analysis

# %% [markdown]
# In this notebook, I will try to compare the tweets of Donald Trump, Barrack Obama, and Hillary Clinton to come up with meaningful insights

# %% [markdown]
# Data:
# There are 3 CSV files which will be used:
# 1. DonaldTrump
# 2. BarackObama
# 3. HillaryClinton
#
# All 3 have the same structure
# sl no,date,id,link,retweet,text,author

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# Read the data

# %%
trump = pd.read_csv("data/DonaldTrump.csv")
obama = pd.read_csv("data/BarackObama.csv")
clinton = pd.read_csv("data/HillaryClinton.csv")

# %% [markdown]
# Check out the data

# %%
trump.head()
# Out:
#    Unnamed: 0    date                  id  \
# 0           0   Oct 7  784609194234306560
# 1           1  Oct 10  785608815962099712
# 2           2   Oct 8  784840992734064640
# 3           3  Oct 11  785979396620324864
# 4           4  Oct 10  785561269571026944
#
#                                          link  retweet  \
# 0  /realDonaldTrump/status/784609194234306560    False
# 1  /realDonaldTrump/status/785608815962099712    False
# 2  /realDonaldTrump/status/784840992734064641    False
# 3  /realDonaldTrump/status/785979396620324865    False
# 4  /realDonaldTrump/status/785561269571026946    False
#
#                                                 text       author
# 0    Here is my statement.pic.twitter.com/WAZiGoQqMQ  DonaldTrump
# 1  Is this really America? Terrible!pic.twitter.c...  DonaldTrump
# 2  The media and establishment want me out of the...  DonaldTrump
# 3  Wow, @CNN Town Hall questions were given to Cr...  DonaldTrump
# 4  Debate polls look great - thank you!\n#MAGA #A...  DonaldTrump

# %%
obama.head()
# Out:
#    Unnamed: 0             date                  id  \
# 0           0  20h20 hours ago  786982739517943808
# 1           1  18h18 hours ago  787010142378332160
# 2           2  16h16 hours ago  787039774330748928
# 3           3  21h21 hours ago  786964419905523712
# 4           4           Oct 13  786680553617629184
#
#                                      link  retweet  \
# 0  /BarackObama/status/786982739517943808    False
# 1  /BarackObama/status/787010142378332160    False
# 2  /BarackObama/status/787039774330748928    False
# 3  /BarackObama/status/786964419905523712    False
# 4  /BarackObama/status/786680553617629185    False
#
#                                                 text       author
# 0  Denying climate change is dangerous. Join @OFA...  BarackObama
# 1  The American Bar Association gave Judge Garlan...  BarackObama
# 2  We need a fully functional Supreme Court. Edit...  BarackObama
# 3  Cynics, take note: When we #ActOnClimate, we b...  BarackObama
# 4  "That’s how we will overcome the challenges we...  BarackObama

# %%
clinton.head()
# Out:
#    Unnamed: 0               date                  id  \
# 0           0              Oct 9  785272428905791488
# 1           1              Oct 9  785325012152713216
# 2           2              Oct 9  785282982261190656
# 3           3    7m7 minutes ago  786963642080227328
# 4           4  29m29 minutes ago  786958117531742208
#
#                                         link  retweet  \
# 0  /HillaryClinton/status/785272428905791489    False
# 1  /HillaryClinton/status/785325012152713216    False
# 2  /HillaryClinton/status/785282982261190656    False
# 3  /HillaryClinton/status/786963642080227328    False
# 4  /HillaryClinton/status/786958117531742208    False
#
#                                                 text          author
# 0        Remember. #Debatepic.twitter.com/rlMbTt5WwY  HillaryClinton
# 1  She won. http://hrc.io/2dQkjip  #Debatepic.twi...  HillaryClinton
# 2        Let's go. #Debatepic.twitter.com/HD3ZVJ9xl8  HillaryClinton
# 3  "Everyone knows how bright she is and how resi...  HillaryClinton
# 4  "All the progress we've made these last 8 year...  HillaryClinton

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# A couple of issues have been identified by eye-balling.
# 1. There is an unnamed column which is unnecessary and must be dropped
# 2. ID, and link are not required as well
# 3. Date format is not standard
# 4. Since this is a tweet, it contains many non-alphanumeric characters as well

# %%
#Dropping the unnecessary columns
drop_cols = ["Unnamed: 0", "id", "link"]
trump.drop(drop_cols, axis=1, inplace=True)
obama.drop(drop_cols, axis=1, inplace=True)
clinton.drop(drop_cols, axis=1, inplace=True)

trump.head()
# Out:
#      date  retweet                                               text  \
# 0   Oct 7    False    Here is my statement.pic.twitter.com/WAZiGoQqMQ
# 1  Oct 10    False  Is this really America? Terrible!pic.twitter.c...
# 2   Oct 8    False  The media and establishment want me out of the...
# 3  Oct 11    False  Wow, @CNN Town Hall questions were given to Cr...
# 4  Oct 10    False  Debate polls look great - thank you!\n#MAGA #A...
#
#         author
# 0  DonaldTrump
# 1  DonaldTrump
# 2  DonaldTrump
# 3  DonaldTrump
# 4  DonaldTrump

# %%
#For our analysis, we do not need non-alphanumeric characters like "%^&*() etc"  
text = "jeanf34%#$@asdfass svdaomve;l34 34 23; 2 l4 reldcxzf; "
i=0
text.replace()
# Out:
# Remember. #Debatepic.twitter.com/rlMbTt5WwY
# She won. http://hrc.io/2dQkjip  #Debatepic.twitter.com/C4MP8cPONF
# Let's go. #Debatepic.twitter.com/HD3ZVJ9xl8
# "Everyone knows how bright she is and how resilient she is, but...they're going to see how much she cares." —@JoeBidenpic.twitter.com/QYF2Ewy55Y
# "All the progress we've made these last 8 years is on the ballot." —@POTUS
#
# Make sure you're ready to vote:http://IWillVote.com
# "You have a chance to reject the politics of fear. You can lift up again the politics of hope.” —@POTUS http://IWillVote.com
# "Change is possible, but it doesn’t just depend on one person—it depends on all of us.” —@POTUS http://hillaryclinton.com/volunteer  #StrongerTogether
# "She knows that in a democracy as big and diverse as this, we can't demonize each other.” —@POTUS on Hillary
# "He may be up at 3am, but it’s because he’s tweeting insults at somebody who got under his skin.” —@POTUS on Trump
# “She's got the knowledge and experience and the temperament to be the next Commander-in-Chief.” —@POTUS on Hillary
# "She's in the arena for you, fighting every day to make sure everybody gets a fair shake.” —@POTUS on Hillary
# "Hillary is one of the smartest, toughest, best-prepared, most experienced candidates to ever run for this job.” —@POTUS
# "You can go vote early right now. Early voting started on Wednesday...go to http://IWillVote.com/locate ." —@POTUS in Ohio
# What's "smart" about not funding America's military, schools, or health care for kids?http://hrc.io/2e3q3Fq
# "If you vote for someone other than Hillary—or if you don't vote at all—then you are helping to elect her opponent." —@FLOTUSpic.twitter.com/KNVEzwjPaT
# "If we let Hillary's opponent win this election, then we are sending a clear message to our kids." —@FLOTUS http://IWillVote.com pic.twitter.com/wU4W9Dh9u8
# Every minute of Michelle Obama’s 30 minute speech today is worth watching.http://www.snappytv.com/tc/3005336
# .@FLOTUS, I'm in awe. Thanks for putting into words what's in so many of our hearts. -H
# Coming out often takes incredible courage. On #NationalComingOutDay, let's honor that courage by showing LGBT Americans we're with them.pic.twitter.com/LBhyK1Ounm
# Every single American deserves full equality under our laws—no matter who you are or who you love. #NationalComingOutDaypic.twitter.com/clQIZsXcyk
# "I can't imagine how Governor Pence can defend the insult-driven, selfish, me-first style of Donald Trump." —@TimKaine #VPDebate
# Thanks for the kind words, Mike. #VPDebatepic.twitter.com/DfObNG1PM3
# RT to let @TimKaine know you've got his back tonight. #VPDebatepic.twitter.com/XzjUE0cfnp
# Number of times Trump has tweeted at @Rosie: 65
#
# Number of times Trump has tweeted in support of Mike Pence, his running mate: 21 #VPDebate
# .@TimKaine's spent his whole life fighting for working families, so I have no doubt he'll do the same tonight. Go get 'em, Tim. -H
# If Trump's decisiveness in choosing Mike Pence as his running mate is any indication, he'll be great at making hard decisions as president.pic.twitter.com/nuqjdkqAEk
# Before Mike Pence takes the debate stage to defend his running mate, remember the time Trump couldn't decide whether he wanted him at all.pic.twitter.com/DHJ5iibHnP
# Post-traumatic stress isn't something strong people can handle & weak people can't.
#
# Trump’s comments aren't just ignorant, they’re harmful.
# .@TimKaine is going to finish this campaign the same way he started his career—fighting for working families.pic.twitter.com/c2VlpSRaSM
# Tonight, Mike Pence will either have to leave Trump out to dry—or try to justify the things they both believe. #VPDebatepic.twitter.com/9PXYCR6zXN
# Contributing nothing to our military, public schools, kids' health care, and more doesn't make you "smart."pic.twitter.com/HKAvxfCigr
# White people need to empathize and understand what it’s like for black parents to worry about their kids' safety.http://www.snappytv.com/tc/2941357
# "I've known Hillary since September of 1958...we were just thinking of the next Nancy Drew book." —Hillary's lifelong friend, Betsypic.twitter.com/nVs01awNQ6
# Mike Pence: a divisive, anti-woman, anti-LGBT, anti-worker extremist.
#
# No wonder Trump picked him. #VPDebatepic.twitter.com/icAN1P5DN2
# .@TimKaine wears his "F" rating from the @NRA like a badge of honor.http://hrc.io/2dohCDY
